# %% [markdown]
# <a href="https://colab.research.google.com/github/FIJY/hh/blob/master/%D0%9F%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3_hh(%D1%80%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9_%D0%B2%D0%B0%D1%80%D0%B8%D0%B0%D0%BD%D1%82).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Парсинг с сайта hh <br>
# Ссылка на видео парсинга hh https://yandex.ru/video/preview/11468178118806870731

# %% [markdown]
# ## Устанавливаем и импортируем библиотеки

# %%
# Устанавливаем библиотеки
# requests для отправки запросов
# BeautifulSoup для разбора полученных данных
# lxml для парсинга
# fake_useragent для создания заголовков
# !pip install requests (requests в colab можно не устанавливать)
# !pip install bs4
# !pip install lxml (lxml в colab можно не устанавливать)
# !pip install fake_useragent
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Collecting fake_useragent
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: fake_useragent
# Successfully installed fake_useragent-1.5.1

# %%
# Импортируем библиотеки
import requests
from bs4 import BeautifulSoup
import fake_useragent
import time
import json
import pandas as pd
import re
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Парсинг hh

# %%
# Заходим на hh, выбираем регион (Россия)
# Вводим запрос в поле поиска (например python) в разделе Соискателям
# Переходим на вкладку резюме
# Переходим на вторую страницу, чтобы появился параметр page
# Копируем адрес страницы

# %% [markdown]
# ### Создание параметров поиска резюме, <br>получение ссылки-запроса для последующего парсинга ссылок резюме.  <br><br> Источник параметров поиска <br> https://github.com/EvgenyTerebenin/hh-api/blob/master/docs/resumes_search.md

# %%
# Функция создания ссылки для поиска резюме по заданным параметрам

def ref_search_resume (text: str, what_search = 'normal', list_search = ['full_text'],
                       sorting = 'relevance', date_period = 0, date_min = None,
                       date_max = None, quantity_items = 20, areas = [113],
                       arg_relocation = "living_or_relocation", exp_industry = None,
                       exp_period = 'all_time', job_search = None, age_min = None,
                       age_max = None, age_if = False, employments = None,
                       schedules = None, experiences = None, prof_roles = None,
                       gen = "unknown", gender_if = False, salary_min = None,
                       salary_max = None, currency = "RUB", salary_if = False,
                       countries = None, foto_if = False, vehicle_if = False,
                       educations = None, universities = None, ver_skills = None,
                       key_skills = None, work_countries = None,
                       driver_types = None, languages = None,
                       verif_languages = None):

  '''
  Функция создания ссылки для поиска резюме по заданным параметрам.

  :text: Слово или фраза для поиска резюме.

  :what_search = 'normal': Какие слова использовать в поиске
  "Все слова": normal,
  "Любое из слов": any,
  "Точная фраза": phrase,
  "Не встречаются": except

  :list_search = ['full_text']: Где искать указанные слова
  "Везде": full_text,
  "В названии резюме": position,
  "В образовании": education,
  "В ключевых навыках": keywords,
  "В опыте работы": workplaces
  При уточнении можно подавать несколько, списком, но не более трех,
  иначе будет вариант "Везде".

  :sorting = 'relevance': Способ сортировки списка резюме.
  "По дате изменения": publication_time,
  "По убыванию зарплат": salary_desc,
  "По возрастанию зарплаты": salary_asc,
  "По соответствию": relevance

  :date_period = 0: За какой период искать
  "За все время": 0,
  "За сутки": 1,
  "За последние три дня": 3,
  "За неделю": 7,
  "За месяц": 30,
  "За год": 365

  :date_min = None  date_max = None: Интервал поиска между датами
  Формат указания дат ДД.ММ.ГГГГ

  :quantity_items = 20: Количество резюме на одной странице
  Можно указывать любое количество. Стандартный выбор: 20, 50, 70, 100

  :areas = [113]: Регион поиска
  Можно выбирать несколько, подается список кодов регионов
  Источник https://api.hh.ru/areas
  Обозначения некоторых регионов:
  Россия: 113,
  Москва: 1, Московская область: 2019,
  Санкт-Петербург: 2, Ленинградская область: 145,
  Екатеринбург: 3, Свердловская область: 1261,
  Новосибирск: 4, Новосибирская область: 1202,
  Нижний Новгород: 66, Красноярск: 54, Челябинск: 104, Самара: 78, Уфа: 99,
  Краснодар: 53, Ростов-на-Дону: 76, Омск: 68, Воронеж: 26, Пермь: 72, Волгоград: 24,
  Татарстан: 1624, Казань: 88

  :arg_relocation = "living_or_relocation": Переезд
  Источник
  https://api.hh.ru/openapi/redoc#tag/Obshie-spravochniki/operation/get-dictionaries
  Варианты, подается один из вариантов:
  "living_or_relocation" - Живут в указанном регионе или готовы переехать в него,
  "living" - Живут в указанном регионе,
  "living_but_relocation" - Живут в указанном регионе и готовы к переезду куда-либо,
  "relocation" - "Не живут в указанном регионе, но готовы переехать в него"

  :exp_industry = None: Опыт работы в отрасли
  Указывается требуемая отрасль;
  По умолчанию выбраны все отрасли
  Можно выбирать несколько, подается списком кодов отраслей
  Источник https://api.hh.ru/industries
  "Информационные технологии, системная интеграция, интернет": "7",
  включает в себя:
  "Интернет-провайдер": "7.538",
  "Системная интеграция,  автоматизации технологических и
  бизнес-процессов предприятия, ИТ-консалтинг": "7.539",
  "Разработка программного обеспечения": "7.540",
  "Интернет-компания (поисковики, платежные системы, соц.сети,
  информационно-познавательные и развлекательные ресурсы,
  продвижение сайтов и прочее)": "7.541"

  :exp_period = 'all_time': Период работы в отрасли, указывается вместе с опытом работы
  Источник
  https://api.hh.ru/openapi/redoc#tag/Poisk-rezyume/operation/search-for-resumes
  Варианты, выбирается один из вариантов:
  "all_time" - за всё время работы;
  "last_year" - за последний год;
  "last_three_years" - за последние 3 года;
  "last_six_years" - за последние 6 лет

  :job_search = None: Статус поиска работы
  Варианты, можно выбирать несколько, подается списком:
  "unknown" - Без статуса поиска;
  "not_looking_for_job" - Не ищет работу;
  "looking_for_offers" - Рассматривает предложения;
  "active_search" - Активно ищет работу;
  "has_job_offer" - Предложили работу, решает;
  "accepted_job_offer" - Вышел на новое место

  :age_min = None  age_max = None: Возраст, от и до
  :age_if = False: Найти резюме только с возрастом
  (по умолчанию фильтр отсутствует)

  :employments = None: Тип занятости
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "full" - Полная занятость;
  "part" - Частичная занятость;
  "project" - Проектная работа;
  "probation" - Стажировка;
  "volunteer" - Волонтерство

  :schedules = None: График работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "fullDay" - Полный день;
  "remote" - Удаленная работа;
  "flexible" - Гибкий график;
  "shift" - Сменный график;
  "flyInFlyOut" - Вахтовый метод

  :experiences = None: Опыт работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "moreThan6" - Более 6 лет;
  "between3And6" - От 3 до 6 лет;
  "noExperience" - Нет опыта;
  "between1And3" - От 1 года до 3 лет

  :prof_roles = None: Специализации
  По умолчанию не указаны
  Перечень кодов специализаций (направление "Информационные технологии"),
  можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/professional_roles
  "BI-аналитик, аналитик данных": 156,
  "DevOps-инженер": 160,
  "Аналитик": 10,
  "Арт-директор, креативный директор": 12,
  "Бизнес-аналитик": 150,
  "Гейм-дизайнер": 25,
  "Дата-сайентист": 165,
  "Дизайнер, художник": 34,
  "Директор по информационным технологиям (CIO)": 36,
  "Менеджер продукта": 73,
  "Методолог": 155,
  "Программист, разработчик": 96,
  "Продуктовый аналитик": 164,
  "Руководитель группы разработки": 104,
  "Руководитель отдела аналитики": 157,
  "Руководитель проектов": 107,
  "Сетевой инженер": 112,
  "Системный администратор": 113,
  "Системный аналитик": 148,
  "Системный инженер": 114,
  "Специалист по информационной безопасности": 116,
  "Специалист технической поддержки": 121,
  "Тестировщик": 124,
  "Технический директор (CTO)": 125,
  "Технический писатель": 126,
  "Другое": 40

  :gen = "unknown": Пол
  "unknown" - не имеет значения;
  "male" - мужской;
  "female" - женский

  :gender_if = False: Показать резюме с указанием пола
  По умолчанию фильтр отсутствует

  :salary_min = None: Зарплата от
  :salary_max = None: Зарплата до
  :currency = "RUB": Валюта
  Можно задать в евро EUR или в долларах USD

  :salary_if = False: Показать резюме только где указан доход
  По умолчанию фильтр отсутствует

  :countries = None: Гражданство, страна
  Перечень некоторых кодов стран, можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :foto_if = False  vehicle_if = False: Есть фото, автомобиль
  По умолчанию фильтры отсутствуют

  :educations = None: Образование
  Перечень видов образования, можно выбирать несколько, подается список названий:
  "Среднее": secondary,
  "Среднее специальное": special_secondary,
  "Незаконченное высшее": unfinished_higher,
  "Бакалавр": bachelor,
  "Магистр": master,
  "Высшее": higher,
  "Кандидат наук": candidate,
  "Доктор наук": doctor

  :universities = None: Учебное заведение
  Перечень кодов некоторых учебных заведений, можно выбирать несколько,
  подается список кодов:
  Источник https://app.psal.ru/api/university/
  "МГУ": 39144,
  "Национальный исследовательский университет ИТМО": 39872,
  "НИЯУ МИФИ": 39650,
  "МГТУ им. Н.Э. Баумана": 38921

  :ver_skills = None: Подтвержденные навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  "Python": 1114,
  "MS Excel": 845,
  "SQL": 1252,
  "Git": 3215,
  "HTML": 598,
  "ООП": 2350,
  "JavaScript": 674,
  "Agile Project Management": 998,
  "Scrum": 3193,
  "Копирайтинг": 2097,
  "AutoCAD": 153

  :key_skills = None: Ключевые навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  'Python': 1114, 'SQL': 1252, 'Git': 3215, 'Linux': 730, 'Английский язык': 5488,
  'HTML': 598, 'MS Excel': 845, 'JavaScript': 674, 'Работа в команде': 4118,
  'MySQL': 893, 'PostgreSQL': 1063, 'MS PowerPoint': 866, 'C++': 231, 'CSS': 351,
  'Управление проектами': 2924, 'ООП': 2350, 'Пользователь ПК': 3864,
  'Adobe Photoshop': 87, 'Java': 3093, 'Организаторские навыки': 2366,
  'Грамотная речь': 1827, 'C#': 230, 'HTML5': 7161, 'Ведение переговоров': 1691,
  'PHP': 3750, 'Работа с большим объемом информации': 6958, 'C/C++': 144745,
  'MS Word': 883, 'Деловая переписка': 1855, 'Django Framework': 416,
  'Atlassian Jira': 142, 'Анализ данных': 1534, 'MS SQL': 871,
  'Аналитическое мышление': 14886, 'MATLAB': 791, 'Bash': 4070, 'CSS3': 3512,
  'Деловое общение': 1857, 'Математическая статистика': 2190, 'MS Outlook': 860,
  'AutoCAD': 153, 'Data Analysis': 372, 'jQuery': 687,
  'Управление персоналом': 2917, 'Scrum': 3193, 'Базы данных': 8540,
  'Работа с базами данных': 17049, 'Проведение презентаций': 2514,
  'Деловая коммуникация': 1853, 'Agile Project Management': 99

  :work_countries = None: Разрешение на работу, страна
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :driver_types = None: Категория прав
  Перечень категорий, можно выбирать несколько, подается список категорий:
  B, C, A, BE, D, E, CE, DE, Tm (трамвай), Tb (троллейбус)

  :languages = None: Знание языков, уровень
  Можно выбирать несколько, подается список языков
  Перечень некоторых языков:
  Источник https://api.hh.ru/languages
  "Русский": rus, 34;
  "Английский": eng, 57;
  "Французский": fra, 59;
  "Немецкий": deu, 58;
  "Белорусский": bel, 7;
  "Китайский": zho, 20
  С языком указывается уровень владения, например "eng.a1"
  Перечень уровней владения языком:
  a1 - Начальный, a2 - Элементарный,
  b1 - Средний, b2 - Средне-продвинутый,
  c1 - Продвинутый, c2 - В совершенстве,
  l1 - Родной язык

  :verif_languages = None: Подтвержденные знания
  (указываются только по английскому языку)
  Перечень кодов подтвержденных знаний:
  "a1 Начальный": 57.1;
  "a2 Элементарный": 57.2;
  "b1 Средний": 57.3;
  "b2 Средне-продвинутый": 57.4;
  "c1 Продвинутый": 57.5;
  "c2 В совершенстве": 57.6
  '''
  # Слово/фраза для поиска резюме
  # Перед подачей в url заменим в text пробелы и другие символы (,;) на url-коды
  text = text.replace(" ", "+").replace(",", "%2C").replace(";", "%3B")

  # Какие слова использовать в поиске
  # what_search = 'any'
  # what_search = 'phrase'
  # what_search = 'except'
  logic = f'&logic={what_search}'

  # Где искать указанные слова
  # list_search = ['keywords', 'position']
  # list_search = ['keywords', 'position', 'education', 'workplaces']
  # list_search = ['keywords']
  if (len(list_search) < 4):
    where_search = '%2C'.join(list_search)
  else:
    where_search = 'full_text'
  pos = f'&pos={where_search}'

  # Способ сортировки списка резюме
  # sorting = 'salary_desc'
  order_by = f'&order_by={sorting}'

  # За какой период искать
  date_period = 30

  # Интервал поиска между датами
  # date_min = '01.03.2024'
  # date_max = '15.03.2024'
  if (date_min and date_max):
    search_period = f'&search_period=-1&date_from={date_min}&date_to={date_max}'
  else:
    search_period = f'&search_period={date_period}'

  # Количество резюме на одной странице
  # quantity_items = 5
  items_on_page = f'&items_on_page={quantity_items}'

  # Регион поиска
  # areas = [113, 4]
  area = ''.join(f'&area={region}' for region in areas)

  # Переезд
  # arg_relocation = "living"
  relocation = f'&relocation={arg_relocation}'

  # Опыт работы в отрасли
  # exp_industry = [7] # Подается списком кодов отраслей
  # exp_industry = [7.538, 7.540, 7.541]
  filter_exp_industry = ''
  if exp_industry:
    filter_exp_industry = ''.join(f'&filter_exp_industry={exp_industry:.3f}'
                                  if isinstance(exp_industry, float)
                                  else f'&filter_exp_industry={int(exp_industry)}'
                                  for exp_industry in exp_industry)

  # Период опыта работы в отрасли
  # exp_period = "last_year"
  filter_exp_period = f'&filter_exp_period={exp_period}'

  # Статус поиска работы
  # job_search = ["looking_for_offers", "has_job_offer"]
  job_search_status = ''
  if job_search:
    job_search_status = ''.join(f'&job_search_status={search}'
                                for search in job_search)

  # Возраст
  # age_min = 35
  # age_max = 45
  # age_if = True
  age_from = ''
  age_to = ''
  label_age = ''
  if age_min: age_from = f'&age_from={age_min}'
  if age_max: age_to = f'&age_to={age_max}'
  if age_if: label_age = f'&label=only_with_age'

  # Тип занятости
  # employments = ['part', 'probation']
  employment = ''
  if employments:
    employment = ''.join(f'&employment={empl}' for empl in employments)

  # График работы
  # schedules = ['remote', 'flexible']
  schedule = ''
  if schedules:
    schedule = ''.join(f'&schedule={sched}' for sched in schedules)

  # Опыт работы
  # experiences = ['between1And3']
  experience = ''
  if experiences:
    experience = ''.join(f'&experience={exper}' for exper in experiences)

  # Специализации
  # prof_roles = [96, 40, 156]
  professional_role = ''
  if prof_roles:
    professional_role = ''.join(f'&professional_role={prof_role}'
                                for prof_role in prof_roles)

  # Пол
  # gen = "male"
  # gen = "female"
  # gender_if = True
  gender = f'&gender={gen}'
  label_gender = ''
  if gender_if: label_gender = f'&label=only_with_gender'

  # Уровень дохода
  # salary_min = 500
  # salary_max = 1000
  # currency = 'EUR'
  # currency = 'USD'
  # salary_if = True
  salary_from = ''
  salary_to = ''
  label_salary = ''
  currency_code = ''
  if currency in ['EUR', 'USD']: currency_code = f'&currency_code={currency}'
  if salary_min: salary_from = f'&salary_from={salary_min}'
  if salary_max: salary_to = f'&salary_to={salary_max}'
  if salary_if: label_salary = f'&label=only_with_salary'

  # Гражданство, страна
  # countries = [113, 16]
  citizenship = ''
  if countries:
    citizenship = ''.join(f'&citizenship={country}' for country in countries)

  # Есть фото, есть  автомобиль
  # foto_if = True
  # vehicle_if = True
  label_foto = ''
  label_vehicle = ''
  if foto_if: label_foto = f'&label=only_with_photo'
  if vehicle_if: label_vehicle = f'&label=only_with_vehicle'

  # Образование
  # educations = ['higher', 'candidate']
  education_level = ''
  if educations:
    education_level = ''.join(f'&education_level={education}'
                              for education in educations)

  # Учебное заведение
  # universities = [39872, 39650]
  university = ''
  if universities:
    university = ''.join(f'&university={univer}' for univer in universities)

  # Подтвержденные навыки
  # ver_skills = [1114, 845, 2350]
  verified_skills = ''
  if ver_skills:
    verified_skills = ''.join(f'&verified_skills={verif_skill}'
                              for verif_skill in ver_skills)

  # Ключевые навыки
  # key_skills = [3093, 6958, 14886, 1114]
  skill = ''
  if key_skills:
    skill = ''.join(f'&skill={key_skill}' for key_skill in key_skills)

  # Разрешение на работу, страна
  # work_countries = [16, 213]
  work_ticket = ''
  if work_countries:
    work_ticket = ''.join(f'&work_ticket={work_country}'
                          for work_country in work_countries)

  # Категория прав
  # driver_types = ['B', 'C']
  driver_license_types = ''
  if driver_types:
    driver_license_types = ''.join(f'&driver_license_types={type_drive}'
                                   for type_drive in driver_types)

  # Знание языков, уровень
  # Дополнительно по английскому языку можно указать подтвержденные знания
  # languages = ['rus.l1', 'bel.c2', 'eng.c1', 'zho.b1']
  # verif_languages = '57.5'
  language = ''
  if languages:
    language = ''.join(f'&language={lang}' for lang in languages)
  verified_languages = ''
  if languages:
    verified_languages = f'&verified_languages={verif_languages}'

  # Создаем ссылку для поиска резюме по заданным параметрам
  base_url=\
  f"https://hh.ru/search/resume?text={text}{area}&isDefaultArea=true\
&exp_period=all_time{logic}{pos}{order_by}{search_period}{items_on_page}{relocation}\
{filter_exp_industry}{filter_exp_period}{job_search_status}{age_from}{age_to}\
{label_age}{employment}{schedule}{experience}{professional_role}{gender}\
{label_gender}{currency_code}{salary_from}{salary_to}{label_salary}\
{citizenship}{label_foto}{label_vehicle}{education_level}{university}\
{verified_skills}{skill}{work_ticket}{driver_license_types}{language}\
{verified_languages}"

  return base_url

# %% [markdown]
# ### Функция парсинга ссылок резюме

# %%
# Создаем объект для передачи заголовка
# Создадим юзер-агента, общего для всех запросов
ua = fake_useragent.UserAgent()

# %%
# Функция для получения ссылок по запросу
def get_links(base_url):

  data = requests.get(
      url=base_url,
      headers = {"user-agent":ua.random})

  # Если произошла ошибка, выходим из функции
  if data.status_code != 200:
    print(f"Ошибка запроса: HTTP {data.status_code}")
    return

  # В переменную soup передаем содержание полученной страницы
  soup = BeautifulSoup(data.content, "lxml")
  # Найдем количество страниц
  # Внизу открытой страницы hh находим количество страниц 250; нажимаем правой кнопкой мыши и далее "Проверить"
  # В открывшемся справа окне, вверху нажимаем кнопку проверить и выбираем количество страниц (250)
  # Находим div class = "pager", и вводим его в attrs
  # Далее надо найти все "span" и взять последний, т.к. там указано 250
  # Далее у последнего span надо получить ссылку "a"
  # В ссылке надо взять "span", и в "span" взять текст
  # Полученное значение переводим в int
  try:
    page_count = int(soup.find("div", attrs={"class":"pager"}).find_all("span",recursive=False)[-1].find("a").find("span").text)
  except Exception as e:
    print("Ошибка при получении количества страниц: ", e)
    return

  for page in range(page_count):
    try:
      # Создаем заголовок и передаем туда случайный заголовок из созданного объекта
      # В запрос передаем страницу
      data = requests.get(
        url=f"{base_url}&page={page}",
        headers = {"user-agent":ua.random}
      )

      if data.status_code != 200:
        print(f"Пропуск страницы {page} из-за ошибки HTTP {data.status_code}")
        continue
      soup = BeautifulSoup(data.content, "lxml")
      # Выбираем на hh любое резюме, нам нужна ссылка "a", у нее нужен атрибут "data-qa"; этот атрибут вставляем в soup
      # Проходим по всем ссылкам
      for a in soup.find_all("a", attrs={"data-qa":"serp-item__title"}):
        # в каждой ссылке "a" нам нужен адрес сайта в "attrs"
        # в адресе сайта нужно всё до знака "?", поэтому разбиваем ссылку по знаку "?" и берем первый элемент
        yield f"https://hh.ru{a.attrs['href'].split('?')[0]}"
    except Exception as e:
      print(f"Ошибка при обработке страницы {page}: {e}")
    time.sleep(1)

# %% [markdown]
# # Функция парсинга информации из каждого резюме

# %%
# Функция для получения данных резюме
def get_resume(link):

  # Делаем запрос к переданной ссылке
  data = requests.get(
      url = link,
      headers={"user-agent":ua.random}
  )
  if data.status_code != 200:
    return

  soup = BeautifulSoup(data.content, "lxml")

  id_link = "",
  gender = "",
  age = "",
  date_of_birth = "",
  about_me = "",
  education = "",
  language = "",
  job_search_status = "",
  place_of_residence = "",
  moving = "",
  business_trip = "",
  name = "",
  salary = "",
  specialization_schedule = "",
  experience_all_period = "",
  experience = "",
  tags = "",
  link = ""


  # Вытащим из ссылки id резюме
  id_link = link.split("/")[-1]

  # Спарсим пол (мужчина / женщина)
  try:
    gender = soup.find("span", attrs={"data-qa": "resume-personal-gender"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    gender = ""

  # Спарсим возраст
  try:
    age = soup.find("span", attrs={"data-qa": "resume-personal-age"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    age = ""

  # Спарсим дату рождения
  try:
    date_of_birth = soup.find("span", attrs={"data-qa":"resume-personal-birthday"}).text.replace("\xa0", " ")
  except:
    date_of_birth = ""

  # Спарсим статус поиска работы (Активно ищет работу / Не ищет работу / Рассматривает предложения / и т.д.)
  try:
    job_search_status = soup.find("span", attrs={"data-qa": "job-search-status"}).text
  except:
    job_search_status = ""

  # Спарсим информацию "О себе"
  try:
    about_me = soup.find("div", attrs={"data-qa": "resume-block-skills-content"}).text.strip()
  except:
    about_me = ""

  # Спарсим информацию об образовании
  try:
    # Находим блок образования и извлекаем из него текст
    education_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-education"})
    education = []
    for block in education_blocks:
      education_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
      education.append(education_info)
  except:
    education = []

  # Спарсим информацию о знании языков
  try:
    language_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-languages"})
    language = []
    for block in language_blocks:
      lang_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
      language.append(lang_info)
  except:
    language = []


  # Спарсим место проживания (город, метро)
  # Создадим пустой список, куда будем добавлять "Город", "Метро"
  list_of_residence = []
  # Парсим "Город" и при удачном парсинге добавляем его в пустой список
  city = soup.find("span", attrs={"data-qa":"resume-personal-address"})
  if city: list_of_residence.append(city.text.replace("\xa0", " "))
  # Парсим "Метро" и при удачном парсинге добавляем его в пустой список
  # Не во всех резюме есть "Метро", поэтому делаем проверку удачного парсинга
  metro = soup.find("span", attrs={"data-qa":"resume-personal-metro"})
  if metro: list_of_residence.append(metro.text.replace("\xa0", " "))
  # Соединяем город и метро, и получаем место проживания
  place_of_residence = ', '.join(part_residence for part_residence in list_of_residence).strip()

  # Спарсим готовность к переезду, командировкам
  try:
    # Находим весь текст в блоке "Готовность к переезду/командировкам"
    movings = soup.find(attrs={"class":"bloko-translate-guard"}).text.replace("\xa0", " ")
    # Разделяем текст на части по запятой
    parts = movings.split(',')
    # Создадим пустой список, куда будем добавлять фразы касательно переезда
    moving_list = []
    # Проходимся по частям текста за исключением последней,
    # т.к. последняя часть - это готовность к командировкам
    for part in parts[:-1]:
      # Если часть текста не содержится в "Место проживания"
      # добавляем ее в пустой список
      if part not in place_of_residence:
        moving_list.append(part)
    # Полученный список соединяем и получаем "Готовность к переезду"
    moving = ','.join(part_moving for part_moving in moving_list).strip()
    # Берем последнюю часть, получаем готовность к командировкам
    business_trip = parts[-1].strip()
  except:
    moving = ""
    business_trip = ""

  # Спарсим название позиции
  try:
    name = soup.find(attrs={"class":"resume-block__title-text"}).text
  except:
    name = ""

  # Спарсим зарплату и уберем лишние символы (\u2009, \xa0)
  try:
    salary = soup.find(attrs={"class":"resume-block__salary"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    salary = ""

  # Спарсим специализации и график работы
  try:
    # Находим все блоки с class "resume-block-container"
    specialized_blocks = soup.find_all(attrs={"class":"resume-block-container"})
    # Проверим каждый блок и найдем блок в котором есть class "resume-block__specialization"
    for block in specialized_blocks:
      if block.find(attrs={"class":"resume-block__specialization"}):
        # Запишем в переменную текст найденного блока
        # Предварительно добавив пробелы перед заглавными буквами и затем удалив лишние пробелы (в начале)
        specialization_schedule = re.sub(r'([А-ЯA-Z])', r' \1', block.text).strip()
  except:
    specialization_schedule = ""

  # Спарсим общее время опыта работы
  try:
    experience_all_period = soup.find(attrs={"class":"resume-block__title-text resume-block__title-text_sub"}).text.replace("\xa0", " ")
  except:
    experience_all_period = ""

  # Спарсим опыт работы
  try:
    # Найдем все блоки с class="resume-block-item-gap" в блоке с "data-qa":"resume-block-experience"
    # В самом первом блоке информация дублируется, поэтому список создадим без самого первого элемента
    blocks_item_gap = soup.find(attrs={"data-qa":"resume-block-experience"}).find_all(attrs={"class":"resume-block-item-gap"})[1:]
    # Создадим паттерн для последующего поиска блоков
    reexp = re.compile('bloko-column.*')
    blocks_all = [] # Сюда будем складывать найденные блоки
    experience = [] # Сюда будем складывать итоговый текст
    # Проходимся по каждому вышенайденному блоку и находим все блоки с атрибутом class по заданному паттерну
    for block_item in blocks_item_gap:
      blocks_all.append (block_item.find_all(class_=reexp)[1:]) # Аналогично нам нужен список без самого первого элемента
    # Проходимся по каждому списку блоков в общем списке blocks_all
    for block in blocks_all:
      # Проходимся по каждому элементу
      for data in block:
        # print(data.text.replace("\xa0", " "))
        # Полученный текст из каждого элемента складываем в итоговый список
        experience.append(data.text.replace("\xa0", " "))
  except:
    experience = ""

  # Спарсим ключевые навыки
  # Находим атрибут, где находятся все ключевые навыки (data-qa = "skills-table); далее находим class для каждого отдельного навыка, оставляем class с text
  try:
    tags = [tag.text for tag in soup.find(attrs={"data-qa":"skills-table"}).find_all(attrs={"class":"bloko-tag__section_text"})]
  except:
    tags = []


  # Собираем все найденные атрибуты в словарь, в конце словаря добавляем url-адрес резюме
  resume = {
      "id":id_link,
      "gender":gender,
      "age":age,
      "date_of_birth":date_of_birth,
      "about_me": about_me,
      "education": education,
      "language": language,
      "job_search_status":job_search_status,
      "place_of_residence":place_of_residence,
      "moving":moving,
      "business_trip":business_trip,
      "name":name,
      "salary":salary,
      "specialization_schedule":specialization_schedule,
      "experience_all_period":experience_all_period,
      "experience":experience,
      "tags":tags,
      "link":link
  }
  return resume

# %% [markdown]
# # Функция парсинга и запись результата в csv файл

# %%
# Получаем ссылку-запрос для последующего парсинга ссылок резюме

# Для примера взято ключевое слово для поиска "python"
# и статус соискателя "рассматривает предложения / активно ищет работу"
search = "UI Designer "
base_url = ref_search_resume(search)
base_url
# Out:
# 'https://hh.ru/search/resume?text=UI+Designer+&area=113&isDefaultArea=true&exp_period=all_time&logic=normal&pos=full_text&order_by=relevance&search_period=30&items_on_page=20&relocation=living_or_relocation&filter_exp_period=all_time&gender=unknown'

# %%
# Полученные ссылки соберем в список link_resume
# Для примера спарсил ссылки только с одной страницы
link_resume = [a for a in get_links(base_url)]

# %%
len (link_resume)
# Out:
# 531

# %%
# Записываем полученные ссылки в csv-файл
with open(
    f'//content/drive/MyDrive/Practice2/parsinghh/link_resume_{search}.csv',
    'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    for resume in link_resume:
        writer.writerow([resume])  # Каждая ссылка записывается в новую строку

# %%
# Прочитаем ссылки из файла csv и сохраним в переменную link_resume_from_csv
with open(f'/content/drive/MyDrive/Practice2/parsinghh/link_resume_{search}.csv', 'r') as link_csv:
  link_resume_from_csv = [row[0] for row in csv.reader(link_csv)]

# %%
link_resume_from_csv
# Out:
# ['https://hh.ru/resume/a988d74c0006dd7e420039ed1f577a6b416431',
#  'https://hh.ru/resume/e8733c290005cf020c0039ed1f746f764f3434',
#  'https://hh.ru/resume/cd6318a70007f15eae0039ed1f5950447a524e',
#  'https://hh.ru/resume/476b85f300076878d40039ed1f756d69393178',
#  'https://hh.ru/resume/ef96d5450002cb00040039ed1f443631337948',
#  'https://hh.ru/resume/181756a0000817af6e0039ed1f725933663161',
#  'https://hh.ru/resume/7302bb5d00086c76840039ed1f706b41507443',
#  'https://hh.ru/resume/79f5a5e80007829adf0039ed1f754b49704e74',
#  'https://hh.ru/resume/0ddd615800029705930039ed1f576f4d4f4550',
#  'https://hh.ru/resume/a8c6a68300029124850039ed1f724874637a44',
#  'https://hh.ru/resume/9335ae59000802eda50039ed1f545a5a703543',
#  'https://hh.ru/resume/d60ada8600092d32b30039ed1f6c3354366853',
#  'https://hh.ru/resume/8d4bc78c00055a049d0039ed1f334d50776571',
#  'https://hh.ru/resume/0a2e5ede0003f3c5a50039ed1f765238794238',
#  'https://hh.ru/resume/078397f90003f2ea7b0039ed1f4e584c614467',
#  'https://hh.ru/resume/1fd69e0f00055751380039ed1f7570304b654b',
#  'https://hh.ru/resume/b2a77a61000190981b0039ed1f365379745542',
#  'https://hh.ru/resume/b72b0dd20008a8bfe70039ed1f7970696e596c',
#  'https://hh.ru/resume/cafa4b43000737f5240039ed1f6c52334d4274',
#  'https://hh.ru/resume/247cd7f40007736e340039ed1f336c4a774d6b',
#  'https://hh.ru/resume/d2ecafc1000806c3e50039ed1f5344584e6e34',
#  'https://hh.ru/resume/d7762f2d00034c65b00039ed1f784f7062676c',
#  'https://hh.ru/resume/5f5bc19400054e46720039ed1f36574d327451',
#  'https://hh.ru/resume/18bcdd200001dddb7e0039ed1f30504241594e',
#  'https://hh.ru/resume/860b4f1d00074603380039ed1f6855496e3073',
#  'https://hh.ru/resume/f1910a1600001860cd0039ed1f736563726574',
#  'https://hh.ru/resume/e0514f0e00009d05660039ed1f736563726574',
#  'https://hh.ru/resume/2f53850300077ab5de0039ed1f684370355141',
#  'https://hh.ru/resume/f749a2d3000588047f0039ed1f765561735443',
#  'https://hh.ru/resume/6852ff750005f5a3440039ed1f43574d796763',
#  'https://hh.ru/resume/008e03050001197c400039ed1f786237653746',
#  'https://hh.ru/resume/85721665000864645d0039ed1f31704c615071',
#  'https://hh.ru/resume/8ed3009f00006796ba0039ed1f736563726574',
#  'https://hh.ru/resume/26ab248500040983390039ed1f64786c4c6f46',
#  'https://hh.ru/resume/08d453de00024d28050039ed1f4d6d3165704b',
#  'https://hh.ru/resume/e0c0798c00027e85560039ed1f75367a324244',
#  'https://hh.ru/resume/d4240cd6000642474a0039ed1f596e58674143',
#  'https://hh.ru/resume/21833fdd00018e77f10039ed1f67316d453639',
#  'https://hh.ru/resume/fca94fad000201712a0039ed1f50643647676d',
#  'https://hh.ru/resume/6888b6c20002ba363b0039ed1f7045666b7551',
#  'https://hh.ru/resume/98a8231c000653944d0039ed1f726465546f5a',
#  'https://hh.ru/resume/996ad51f000102a25a0039ed1f68544a383054',
#  'https://hh.ru/resume/f1c957560002a27abe0039ed1f476277627035',
#  'https://hh.ru/resume/631b113000036919e10039ed1f52645a4c4c73',
#  'https://hh.ru/resume/666bf0b7000337acd50039ed1f556f4245656d',
#  'https://hh.ru/resume/caef22ad000670c7b30039ed1f6d4961487a4c',
#  'https://hh.ru/resume/9d6748cb00044a3b700039ed1f474b47754b45']

# %% [markdown]
# ### Парсинг информации из каждого резюме

# %%
# Переходим по любой ссылке в резюме, с указанной зарплатой
# Смотрим код и копируем class заголовка (для этого нажмем "проверить" и выделим заголовок, т.е. название позиции, например Python developer)
# Аналогично скопируем class зарплаты
# Также ищем class ключевых навыков

# %% [markdown]
# ### Парсинг и запись результата в csv файл

# %%
# Функция парсинга резюме по ссылкам и записи результатов в файл
def result_resumes(link_resume: list):
  '''
  :link_resume: список ссылок резюме
  '''

  # Создаем файл csv для записи результатов
  with open(
      f'/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv',
      'w', newline='', encoding='utf-8') as res_file:
      # Названия столбцов
      fieldnames = ['id', 'gender', 'age', 'date_of_birth', 'about_me',
                    'education', 'language', 'job_search_status',
                    'place_of_residence', 'moving', 'business_trip', 'name',
                    'salary', 'specialization_schedule',
                    'experience_all_period', 'experience', 'tags', 'link']
      writer = csv.DictWriter(res_file, fieldnames=fieldnames)
      # Записываем заголовки столбцов
      writer.writeheader()

      for link in link_resume:
        resume_data = get_resume(link)
        if resume_data: # При успешном парсинге резюме
          writer.writerow(resume_data)  # Записываем данные в CSV
        print(resume_data)
        time.sleep(1)

# %%
len (link_resume)
# Out:
# 531

# %%
result_resumes(link_resume_from_csv[:len (link_resume)])
# Out:
# {'id': '', 'gender': 'Male', 'age': '28 years', 'date_of_birth': '6 January 1996', 'about_me': "Живу в г. Минске.\nЖелаемая должность - UX\\UI Designer. \n\nCurrently living in Minsk, Belarus.\nLooking for a job as UX\\UI Designer.\n\n🎨 Design focus:\niOS Apps • Android Apps • MacOS Apps • Web Services • Web Sites • TV Applications • Terminal Interfaces • Interactive and Animation • Design Quality Control\n\n🗜 Tools\nFigma • Principle • Adobe Illustrator  • Miro • Jira • Lucid • Zeplin\n\nБыстро обучаюсь, трудолюбив, коммуникабелен и целеустремлен. \nАнглийский уровня Advanced (с-1).\nСсылка на портфолио  - https://drive.google.com/drive/u/0/folders/1pyKDzMA2dM40oAMKZppB03nTsFlOcIh_ \n\nI'm learning fast, hardworking, sociable and purposeful.\nMy English level is Advanced(c-1) according to the test. \nPortfolio link - https://drive.google.com/drive/u/0/folders/1pyKDzMA2dM40oAMKZppB03nTsFlOcIh_", 'education': ['Higher education2017БИП - Институт правоведения, МинскМеждународного права и юридической психологии , Юрист международник со знанием иностранных языков'], 'language': ['LanguagesRussian — NativeEnglish — C1 — Advanced'], 'job_search_status': 'Actively searching for a job', 'place_of_residence': 'Minsk, metro station Molodezhnaya', 'moving': 'I want to relocate (Russia, Czech Republic, Poland, Germany, Estonia)', 'business_trip': 'prepared for business trips', 'name': 'UX/UI designer', 'salary': '', 'specialization_schedule': 'Specializations: Designer, artist Employment: full time, part time, project work, work placement Work schedule: full day, shift schedule, flexible schedule, remote working', 'experience_all_period': 'Work experience 4 years 4 months', 'experience': ['January 2023 — currently1 year 5 months', "FreelanceMinskUX/UI DesignerTools: Figma, Adobe Illustrator.\n\nResponsibility:\n• UI / UX design of Mobile and Web applications;\n• Conducting UX research, forming hypotheses, prototyping, and UX audit;\n• Layout of the app's web page;\n• Design of marketing and promotional materials ", 'September 2021 — December 20221 year 4 months', "Bamboo AppsMinskUX/UI designerTools: Figma, Zeplin, Jira, Miro/Lucid.app\n\nResponsibility:\n• UI / UX design of Mobile applications;\n• Conducting UX research, forming hypotheses, prototyping, and UX audit;\n• Daily standup's\n• Presenting design decisions on Demo's\n• Work in a big team (including managers and product owner)\n• Creating Jira tickets\n• PPP Tests with developers", 'May 2021 — August 20214 months', "KernelicsMinsk, kernelics.com/IT, System Integration, Internet... Show moreUX/UI DesignerTools: Figma, Clockify\n\nResponsibility:\n• UI / UX design of Mobile and Web applications;\n• Conducting UX research, forming hypotheses, prototyping, and UX audit;\n• Layout of the app's web page;\n• Design of marketing and promotional materials ", 'February 2020 — May 20211 year 4 months', "FreelanceMinskUX/UI DesignerTools: Figma, Adobe Illustrator.\n\nResponsibility:\n• UI / UX design of Mobile and Web applications;\n• Conducting UX research, forming hypotheses, prototyping, and UX audit;\n• Layout of the app's web page;\n• Design of marketing and promotional materials "], 'tags': ['Figma', 'Sketch', 'Miro', 'Adobe XD', 'Principle', 'iOS', 'Mac Os', 'Android', 'Lucid', 'Atlassian Jira', 'Atlassian Confluence', 'Google Analytics', 'Google Tag Manager', 'Яндекс.Метрика', 'Google Optimize', 'Trello'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '28 лет', 'date_of_birth': '2 октября 1995', 'about_me': 'Я Senior UX UI Designer', 'education': ['Неоконченное высшее образование2021Московский государственный университет им. С.Ю.ВиттеПрикладная информатика, Программирование'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Нижний Новгород', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'UX/UI Designer', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 5 лет 3 месяца', 'experience': ['Май 2022 — Май 20242 года 1 месяц', 'Egar Cloudegarnocode.comSenior UX UI DesignerДизайн корпоративного сайта\nВеб приложение\nДизайн система', 'Январь 2022 — Июль 20227 месяцев', 'Kinddakindda.appSenior UX UI DesignerДизайнер интерфейсов\nРазработка Дизайн системы\nWeb Interface\nMobile Interface\n\nБольшую часть работы вел над продуктом\nhttps://cryptodragons.com\nДизайн лендинга и внутренних страниц, разработка веб интерфейса и адаптация под другой blockchain', 'Декабрь 2020 — Декабрь 20211 год 1 месяц', 'Paily.iopaily.io/enUX/UI Designer1) Разработка дизайн системы\n2) Поддержка и дополнение дизайн системы\n3) Дизайн Landing page и внутренних страниц\n4) Разработка личного кабинета со стороны фриланса и со стороны бизнеса\n5) Разработка CJM, UserFlow, Low -Fi мобильного приложения\n6) Написание сценариев и тестирование мобильного приложения\n7) Дизайн мобильного приложения', 'Март 2020 — Декабрь 202010 месяцев', 'ФрилансНижний НовгородWeb DesignРазработка дизайна сайтов', 'Август 2019 — Март 20208 месяцев', 'OptimediaНижегородская область, optimediann.ru/ДизайнерUX/UI \r\nГрафический дизайн (разработка баннеров, визиток, rollup)\r\nВеб дизайн (Создание макетов сайтов desktop и mobile)', 'Март 2019 — Август 20196 месяцев', 'Black SoftWareНижний НовгородUX/UI DesignРазработка дизайна и прототипирование сайтов и мобильных приложений'], 'tags': ['Креативность', 'Web-дизайн', 'Figma', 'Управление проектами', 'Дизайн', 'Photoshop'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '30 лет', 'date_of_birth': '22 марта 1994', 'about_me': 'Ссылка на портфолио: https://www.behance.net/digitalyara\nСсылка на notion: https://digitalyara.notion.site/dffdf446733e47c4984001dbe96b3a7b?v=95d220a96287476e896dbfbec8763f63&pvs=4', 'education': ['Высшее образование2015Дальневосточный федеральный университет, УссурийскЭкономика и менеджмент, Экономика и управление на предприятии (по отраслям)'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутыйКитайский — A2 — Элементарный'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва', 'moving': 'готов к переезду (Россия)', 'business_trip': 'готов к командировкам', 'name': 'UX/UI designer', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: частичная занятость, проектная работа График работы: сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 5 лет 1 месяц', 'experience': ['Август 2023 — по настоящее время10 месяцев', 'Т1Москва, t1.ruИнформационные технологии, системная интеграция, интернет... Показать ещеUX/UI designer- Проработка бизнес задач и отрисовка совместно с руководителем подразделения\n- Создал с нуля и поддерживаю полноценную платформу для управления с/х предприятиями (цифровое сельское хозяйство, b2b)\n- Разработал макеты и флоу для гео портала (работа со спутниковыми данными)\n- Внедрил с нуля и поддерживаю дизайн систему, которая используется на нескольких  проектах\n- Составление тз для дизайнеров и их ревью\n- Отсмотр верстки, тестирование интерфейса (дизайн ревью)\n- Участвовал в конференциях. Защищал продукт  перед стейкхолдерами и потенциальным будущим пользователями системы\n- Оптимизировал бизнес процессы в команде. Внедрил понятный флоу начиная от бизнес задачи заканчивая релизом\n', 'Ноябрь 2021 — Август 20231 год 10 месяцев', 'Finflowsolution (Идеи ИТ-решений, анализ, разработка и интеграция.)finflowsoft.comФинансовый сектор... Показать ещеUX/UI designer• Редизайн платформы денежных переводов с учетом юзабилити для b2b/b2c сегмента\n• Занимался проектированием начальных экранов в приложениях и создание превью в  магазинах для каждого вендора (Google play/Apple play) \n• Создал дизайн систему, которая адаптирует стили и лого в зависимости от вендора (Theme builder)\n• Разработал и поддерживаю дизайн систему как для веб проектов,так и для мобильных приложений\n• Создал раздел в бэкофисе для  b2b/b2c сегмента\n• Проектирование криптокошелька(mobile):\n        - Создание фирменного стиля\n        - Создание информационной архитектуры\n        - Анализ конкурентов\n        - А/Б тестирование \n        - Создание кликабельного прототипа\n• Ревью верстки\n• Решение бизнес-задач по запросу', 'Август 2021 — Ноябрь 20214 месяца', 'Uchi.ruМосква, uchi.ruИнформационные технологии, системная интеграция, интернет... Показать ещеUX designer• Из набросков и замечаний методиста собрал полноценный продукт.\n• Проработка всех возможных пользовательских сценариев.\n• Придумывание уникальных заданий, интересная подача и геймификация.\n• Работа совместно с иллюстратором, подбор референсов.\n• Обзор готового продукта на стадии разработки и внесение изменений.\n• Тестирование интерфейса на пользователях', 'Апрель 2021 — Август 20215 месяцев', 'Dish&fork (Стартап)Перевозки, логистика, склад, ВЭД... Показать ещеUX/UI designer• Создание визуального бренда\n• Прототипирование\n• Создание карты и портрета пользователя\n• Создание целевой страницы\n• Анализ конкурентов \n• Разработка платформы для покупателей/продавцов', 'Май 2019 — Август 20212 года 4 месяца', 'Индивидуальное предпринимательство / частная практика / фрилансСМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеDesigner• Анализ конкурентов\n• Разработка дизайна лендингов, интернет-магазинов, многостраничных сайтов и мобильных приложений\n• Разработка сайтов на Тильде', 'Октябрь 2020 — Апрель 20217 месяцев', 'Hunteryhuntery.ruИнфор ...
# {'id': '', 'gender': 'Мужчина', 'age': '27 лет', 'date_of_birth': '11 мая 1997', 'about_me': 'Дизайном занимаюсь 3 года, есть желание развиваться дальше и обмениваться опытом. Нравится работать над интересными и сложными задачами, к рутине нормально отношусь. Люблю живые встречи с коллегами и спортивные мероприятия', 'education': ['Среднее специальное образование2018Санкт-Петербургский Техникум Железнодорожного ТранспортаЭксплуатация железных дорог, Строительство железных дорог, путь и путевое хозяйство (инженер путей сообщения)'], 'language': ['Знание языковРусский — РоднойАнглийский — A1 — Начальный'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Санкт-Петербург, м. Московская', 'moving': 'хочу переехать', 'business_trip': 'готов к командировкам', 'name': 'UX UI Designer', 'salary': '120000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, проектная работа График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 2 месяца', 'experience': ['Март 2022 — Апрель 20242 года 2 месяца', 'UXARTСанкт-Петербург, uxart.ru/UX/UI DesignerПроведение аналитики. Составление User Flow. Разработка верхнеуровневых и детализированных прототипов. Разработка дизайна для сайтов и мобильных приложений. \nВзаимодействие с программистами и менеджерами для погружения в проект, адаптации дизайна под существующие технические ограничения и требования бизнеса\nРазработка и поддержание UI KIT\nСоздание простой инфографики\nРазработка концептов, презентаций, баннеров, документов\nРабота в режиме многозадачности ( работа над несколькими проектами одновременно)'], 'tags': ['Adobe Photoshop', 'Figma', 'UI', 'UX', 'Прототипирование', 'Cjm', 'User flow', 'Веб-аналитика', 'Анимация', 'Дизайн интерфейсов', 'Проектирование пользовательских интерфейсов', 'Адаптивный дизайн', 'Wireframing', 'UI Kit', 'Интерактивный дизайн', 'Miro'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '32 года', 'date_of_birth': '26 января 1992', 'about_me': 'Привет, меня зовут Марсель! Я\xa0Middle+ UX/UI дизайнер. \n\nИмею опыт работы в создании: интернет-магазинов, корпоративных сайтов, landing pages,  мобильных приложений и CRM-систем. Сейчас в\xa0поиске работы на постоянной основе в сильную команду дизайнеров, разработчиков и\xa0дизайн лидов. \n\nHard skills\n1. Оценка и\xa0приоритизация фич.\n2. Знание графических редакторов: Figma (component properties, autolayout, variants, variables, constraints), Adobe Photoshop, Adobe Illustrator, After Effects, Principle\n3. Базовые навыки 3D моделирования — Cinema 4D\n4. Базовая анимация\n5. Сегментация рынка, рекрутинг респондентов, планирование исследования\n6. Формулирование гипотез. Выбор методики исследования. Сбор и\xa0анализ данных.\n7. Количественные и качественные методы исследований\n8. Методология Design Thinking, Human Сentered Design\n9. Прототипирование интерфейсов. \n10. Юзабилити-тестирование. \n11. А/Б-тестирование.\n12. Знание английского на уровне (B1) и\xa0изучение всей технической литературы на\xa0английском языке\n13. Знания композиции, колористики и типографики.\n\n\nSoft Skills\n1. Таймменеджмент\n2. Постоянное развитие и\xa0обучение\n3. Ответственный подход к разработке продукта\n4. Поддержание духа в\xa0команде\n5. Высокая мотивация делать проекты, которые решают задачи клиента и\xa0пользователей.', 'education': ['Высшее образование (Магистр)2017Российский университет дружбы народов, МоскваИнженерный, ЭНЕРГЕТИКА, ЭНЕРГЕТИЧЕСКОЕ МАШИНОСТРОЕНИЕ И ЭЛЕКТРОТЕХНИКА2015Российский университет дружбы народов, МоскваИнженерный, ЭНЕРГЕТИКА, ЭНЕРГЕТИЧЕСКОЕ МАШИНОСТРОЕНИЕ И ЭЛЕКТРОТЕХНИКА'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — СреднийЯпонский — A2 — Элементарный'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Москва', 'moving': 'готов к переезду (Нидерланды, Швейцария, Южная Корея, Япония, Норвегия)', 'business_trip': 'готов к командировкам', 'name': 'UX/UI Designer', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 7 месяцев', 'experience': ['Июнь 2023 — по настоящее время1 год', 'WazzupМосква, wazzup24.ru/UX/UI Designer Middle+-Пишу гайдлайны\n-Генерирую и проверяю гипотезы\n-Собираю интерактивные прототипы\n-Работаю с UI-Kit, дорабатываю и улучшаю его\n-Взаимодействую с командой дизайнеров, разработкой, бизнес-аналитиками и маркетологами.', 'Апрель 2023 — Октябрь 20237 месяцев', 'Sales GeneratorМосква, sales-generator.ru/СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеUX/UI Designer Senior- Анализировал конкурентов\n- Проводил функциональный анализ\n- Пользовательские и проектные потоки\n- JOB Stories\n- Количественные и качественные методы исследований\n- Каркасы, прототипы низкой и высокой точности\n- Визуальная концепция\n- Работал с дизайн системой\n- Передавал макеты и спецификации в разработку\n- Проводил дизайн ревью\n- Обучал Junior-дизайнеров ', 'Ноябрь 2020 — Апрель 20232 года 6 месяцев', 'Uprock AgencyМосква, www.agency.uprock.ru/UX/UI Designer Middle1. Анализ задач, аудит конкурентов.\n2. Количественные и качественные методы исследований, каркасы, прототипы lo-fi и hi-fi\n3. Визуальная концепция, UI-Kit\n4. Адаптивный веб-дизайн\n5. Микроанимация\n6. Передача макетов в разработку\n7. Дизайн ревью'], 'tags': ['Figma', 'Miro', 'Principle', 'Protopie', 'Adobe Photoshop', 'Google Docs', 'Eagle', 'Количественные и качественные методы исследований', 'Adobe Illustrator', 'Cinema 4D', 'UX', 'Цветокоррекция', 'Ретушь', 'Digital art', 'Концепт-арт', 'Векторная графика', 'Инфографика', 'UX-исследования', 'Usability', 'UI/UX', 'UI Kit', 'CJM', 'Participatory design', 'Empathy map', 'Usability Testing', 'Интерактивный дизайн', 'Human Interface Guidelines', 'Проектирование взаимодействия', 'User Flow'], 'link': ' ...
# {'id': '', 'gender': 'Женщина', 'age': '28 лет', 'date_of_birth': '10 октября 1995', 'about_me': 'Всем привет!\nМеня зовут Лиза и я - UX/UI Designer с опытом 4 года\n\nПортфолио: https://www.behance.net/lisa_sonrisa\n\nДизайн для меня - это коммуникация + инженерный подход. Под инженерным подходом я подразумеваю исследования и проектирование. Эстетичный UI тоже важен, но это лишь упаковка удобного и нужного людям продукта. \nКоммуникация в дизайне - это общение интерфейса с пользователем, бизнеса с клиентом (посредством интерфейса). \nТак что если вы считаете, что дизайнеры просто рисуют что-то красивое - то нам с вами не по пути. Хотя \n\nВ основном работала на проектной деятельности по разработке продуктов в сложных доменных областях (химия, медицина, крипто) по методологии Agile. Проекты долгие и сложные, поэтому есть вся аттрибутика работы в продуктовой компании. Такие вещи как планирование, спринты, эпики, юзер-стори и прочее. \n\nКомпании, с которыми мне довелось поработать:\n- Strateos (химия, биохимия) https://strateos.com/\n- Takeda (фармацевтика) https://www.takeda.com/\n- MigX (работаборка медицинского ПО) https://migx.ch/\n- Quantori (разработка ПО) https://www.quantori.com/\n- AdroitDI (scientific data) https://adroitdi.com/\n\nАнглийский B2\n\nНемного лично обо мне и что я ищу:\n\nЯ коммуникабельная, доброжелательная и отзывчивая. С хорошим чувством юмора (так говорит моя мама). В работе мой вектор внимания направлен на качество продукта. Мне крайне важен адекватный нетоксичный коллектив\n\nРассматриваю преимущественно удаленную работу. Я всегда работала удаленно с добровольным посещением офиса, и это никак не ухудшало мою продуктивность, у меня все отлично с тайм-менеджментом)\n\nБуду рада пообщаться :)', 'education': ['Высшее образование2019Санкт-Петербургский государственный университет телекоммуникаций им. проф. М.А. Бонч-Бруевича, Санкт-ПетербургФакультет Фундаментальной Подготовки, Электроника и Наноэлектроника2017Санкт-Петербургский государственный университет телекоммуникаций им. проф. М.А. Бонч-Бруевича, Санкт-ПетербургРадио Технологий Связи, Инженер-конструктор электронных средств'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Не\xa0ищет работу', 'place_of_residence': 'Санкт-Петербург', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'UX/UI Designer', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 6 лет 9 месяцев', 'experience': ['Октябрь 2023 — по настоящее время8 месяцев', 'AvitoUX/UI designerВнутренний продукт для AB', 'Март 2020 — по настоящее время4 года 3 месяца', 'Индивидуальное предпринимательство / частная практика / фрилансUX/UI DesignerПомогаю малому и среднему бизнесу автоматизировать их бизнес-процессы посредством создания пользовательских интерфейсов.\nПомогаю маленьким стартапам создать дизайн их будущих продуктов', 'Июль 2022 — Сентябрь 20231 год 3 месяца', 'HMNDИнформационные технологии, системная интеграция, интернет... Показать ещеUX/UI Designer (senior)Работаю на проектной деятельности по разработке сложных продуктов (химия, медицина, крипто) по методологии Agile. Проекты долгие и сложные, поэтому есть вся аттрибутика работы в продуктовой компании. Такие вещи как планирование, спринты, эпики, юзер-стори и прочее. \n\nВот чего мне удалось достичь и чем я занимаюсь:\n\n1. Создала и внедрила в студии стандарт ведения фигма файла. Структурированный подход позволил: \n- Избежать казусных ситуаций на проектах, когда разработчики взяли в работу недоделанный дизайн или не тот дизайн\n- Позволили всем участникам проекта быстро ориентироваться в дизайн-макетах\n- Синхронизировать дизайн-макеты и юзер-стори и эпики в Jira\n- Помогает заказчику более ясно видеть будущий продукт\n- Помогает версионировать макет ...
# {'id': '', 'gender': 'Женщина', 'age': '24 года', 'date_of_birth': '3 июля 1999', 'about_me': 'Мое творчество является центральной частью моей жизни, охватывая различные области декоративно-прикладного искусства. Одновременно меня всегда привлекали точные науки, что послужило основой для моего высшего образования в области информатики и информационных систем.\nЭтот уникальный союз двух различных областей формирует мой уникальный бэкграунд. Веб-дизайн стал для меня естественным выбором, поскольку он позволяет объединить мою страсть к творчеству с новыми возможностями информационных технологий.\nМой опыт позволяет мне подходить к решению задач с уникальной перспективой. Моя цель - создавать веб-сайты, которые не только помогают бизнесу, но и улучшают жизнь людей.', 'education': ['Неоконченное высшее образование2024Московский технический университет связи и информатикиИнформатика и информационные системы (заочное отделение), Информационные системы и сетевые технологии'], 'language': ['Знание языковРусский — РоднойАнглийский — A2 — ЭлементарныйПольский — B1 — СреднийУкраинский — C2 — В совершенстве'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва, м. Технопарк', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'UX/UI designer', 'salary': '200000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость График работы: полный день', 'experience_all_period': 'Опыт работы 1 год 4 месяца', 'experience': ['Январь 2024 — по настоящее время5 месяцев', 'Black Mesa ITLead UX/UI designerРазработка', 'Февраль 2023 — Декабрь 202311 месяцев', 'Маркетинговое агенство Goto TopСМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеMiddle UX/UI designer 1. Создание веб-дизайна для различных маркетинговых материалов, включая веб-сайты, баннеры, рекламные объявления и лендинги.\n2. Разработка дизайна пользовательского интерфейса (UI) для веб-приложений и мобильных приложений.\n3. Сотрудничество с командой маркетинга и разработки для создания дизайна, соответствующего бренду и маркетинговым целям компании.\n4. Оптимизация дизайна для улучшения пользовательского опыта и конверсии.\n5. Создание прототипов и макетов для демонстрации концепций дизайна.\n6. Участие во встречах с клиентами для обсуждения требований и предоставления концепций дизайна.\n7. Соблюдение сроков выполнения проектов и учет требований клиентов при создании дизайна.\n8. Использование последних технологий и тенденций в веб-дизайне для создания современных и инновационных дизайнерских решений'], 'tags': ['Figma', 'Tilda', 'Adobe Illustrator', 'Adobe Photoshop', 'Notion', 'Дизайн интерфейсов', 'Веб-дизайн', 'Прототипирование', 'Верстка', 'Web-дизайн'], 'link': ''}
# {'id': '', 'gender': 'Male', 'age': '35 years', 'date_of_birth': '20 May 1988', 'about_me': 'Passionate UI/UX designer with over 7 years of experience in the fields of e-commerce, startups, fintech, e-learning. I created web services, mobile apps, corporate websites, landing pages and mobile games. I have great soft skills and am not afraid of difficulties. Furthermore, I am also well organized and understand the process of creating various interfaces at different stages of development.\n\nSpecialize in: \n- UX/UI design of web apps and websites \n- UX/UI design of mobile apps (iOS & Android) \n- Design Systems & Style Guide \n- Marketing Design \n- Game Design\n\nKey skills: \nPersona analysis, jobs to be done, audience research, user flow, customer journey map, functional analysis, information architecture, functional prototype, wireframes, interactive prototype, terms of reference, design system, visual design, testing, icons, animation, IOS guidelines and Material Design, illustrations, presentations, infographics.', 'education': ['Incomplete higher education2014European Humanities UniversityVisual Design'], 'language': ['LanguagesRussian — NativeEnglish — B1 — Intermediate'], 'job_search_status': 'Actively searching for a job', 'place_of_residence': 'Moscow', 'moving': 'willing to relocate', 'business_trip': 'prepared for business trips', 'name': 'UX/UI Designer', 'salary': '', 'specialization_schedule': 'Specializations: Designer, artist Employment: full time, part time, project work, work placement Work schedule: full day, shift schedule, flexible schedule, remote working', 'experience_all_period': 'Work experience 7 years 1 month', 'experience': ['November 2022 — January 20241 year 3 months', 'Loppi PoppiMinskUX/UI Designer, 2D ArtistInterface design for mobile games in a casual style, Drawing 2D graphics. Card games, dominoes and puzzles.', 'October 2018 — November 20224 years 2 months', 'IntermediaSaint Petersburg, www.intermedia.netIT, System Integration, Internet... Show moreProduct Designer, UX/UI DesignerI designed the interface of an online store and premium tile app, created presentations and promotional materials. Designed a fitness app. Web design, app design and marketing design.', 'January 2017 — September 20181 year 9 months', 'RMAA GroupMoscowMedia, Marketing, Advertising, PR, Design, Production... Show moreUX/UI DesignerDesign and maintenance of web services, landing pages and corporate websites. Advertising design, marketing design.'], 'tags': ['UX', 'UI', 'Дизайн интерфейсов', 'Web Design', 'Figma', 'Adobe Photoshop', 'Adobe Illustrator', 'Проектирование пользовательских интерфейсов', 'Английский язык', '2D Artist', 'Illustration', 'iOS', 'Photoshop', 'Android', 'Material Design', 'Анализ персон', 'jobs to be done', 'исследование аудитории', 'user flow', 'customer journey map', 'функциональный анализ', 'информационная архитектура', 'функциональный прототип', 'вайфпрейминг', 'интерактивный прототип', 'Prototype', 'техническое задание', 'дизайн-система', 'design-system', 'ui kit'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '32 года', 'date_of_birth': '18 марта 1992', 'about_me': 'Моей сильной стороной является знание 3 иностранных языков: анлийский, итальянский, немецкий.\n\nСофт скиллы: эмпатия, умение слушать \n\nХобби: волонтерство, бег', 'education': ['Высшее образование2022Università degli Studi di Perugia Scienze della comunicazione, SciCom2014Московский государственный лингвистический университет, МоскваНемецкого языка'], 'language': ['Знание языковРусский — РоднойАнглийский — C1 — ПродвинутыйИтальянский — C1 — ПродвинутыйНемецкий — B2 — Средне-продвинутый'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'UX/UI designer', 'salary': '100000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 7 лет 9 месяцев', 'experience': ['Март 2023 — по настоящее время1 год 3 месяца', 'NocoderedUX/UI designer\n', 'Июль 2020 — по настоящее время3 года 11 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансМоскваUX/UI designРазработка сайтов на Tilda/Wix\nРазработка прототипов на Figma \n', 'Декабрь 2019 — Август 20211 год 9 месяцев', 'OOO Бизнес ЛифтМоскваИнформационные технологии, системная интеграция, интернет... Показать ещеJunior Web DesignerBeing a Web designer in Marketing Agency "Business Lift", made high conversion websites, resolve the problems with optimizing existing user interface design and tested for intuitively and experience\n', 'Июль 2016 — Август 20162 месяца', 'AcronisМосква, www.acronis.ruИнформационные технологии, системная интеграция, интернет... Показать ещеSupportтехническая поддержка немецкоговорящих клиентов', 'Июль 2014 — Февраль 20158 месяцев', 'Au-pairГермания, www.aupairworld.com/enОбразовательные учреждения... Показать ещеПреподаватель русского языка как иностранногоПреподавание русского как иностранного для детей \nТехнический перевод документов ', 'Январь 2014 — Июль 20147 месяцев', 'Cube-group.ruМосква, cube-group.ruПомощник руководителяРоль аккаунт менджера и административные поручения, помощь руководителю.', 'Февраль 2012 — Декабрь 20131 год 11 месяцев', 'MSK-POLISМосква, msk-polis.ruФинансовый сектор... Показать ещеАссистент руководителяОчень широкий спектр деятельности, ввиду обилия разноплановых задач руководителя. От прямых продаж до работы с базами данных MySQL.'], 'tags': ['Технический перевод', 'Немецкий язык', 'CRM', 'UX', 'UI', 'Adobe Photoshop', 'Web Design', 'Usability', 'Проектирование пользовательских интерфейсов', 'Веб-дизайн', 'Web-дизайн', 'Дизайн интерфейсов', 'Figma', 'Design', 'Верстка', 'Sketch', 'Прототипирование', 'tilda'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '36 лет', 'date_of_birth': '6 ноября 1987', 'about_me': 'Добрый  день. Я веб дизайнер с хорошим опытом в этой сфере. Люблю все что касается дизайна и творчества, немного увлекаюсь медициной, психологией и маркетингом. Всегда на связи, ответственна, трудолюбива, с хорошим чувством юмора) Спасибо что уделили время на просмотр резюме. Буду рада сотрудничеству.', 'education': ['Высшее образование2013Южно-Российский государственный технический университет (Новочеркасский политехнический институт), Ростов-на-ДонуИнформационные технологии, Программное обеспечение вычислительной техники и автоматизированных систем'], 'language': ['Знание языковРусский — РоднойАнглийский — A1 — Начальный'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Тюмень', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'UX/UI designer', 'salary': '100000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость График работы: удаленная работа', 'experience_all_period': 'Опыт работы 14 лет', 'experience': ['Январь 2021 — по настоящее время3 года 5 месяцев', 'ITSoft, компанияМосква, itsoft.ruИнформационные технологии, системная интеграция, интернет... Показать ещеUX/UI designerUX/UI, прототипирование и дизайн интерфейсов, разработка креативных концепций, веб анимация, улучшение пользовательского опыта, создание графики ', 'Апрель 2020 — Январь 202110 месяцев', 'Веб-студия «WW»Тюмень, ww.net.ruИнформационные технологии, системная интеграция, интернет... Показать ещеВеб-дизайнерРазработка макетов веб-сайтов, оформление соц. сетей', 'Май 2018 — Апрель 20202 года', 'Ресторан доставки Pro porciaТюмень, pro-porcia.ruГостиницы, рестораны, общепит, кейтеринг... Показать ещеГрафический дизайнерРазработка креативных концепций для проведения акций,  макетов продукции для соц сетей и полиграфической продукции,упаковки, фоторетушь, анимация, наружная реклама', 'Ноябрь 2015 — Июнь 20182 года 8 месяцев', 'РКК "Стелла"Ростов-на-Дону, rkk-stella.comСМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеГрафический дизайнерРазработка макетов полиграфической продукции.', 'Июль 2014 — Май 201511 месяцев', 'Типография "МастерПринт"Ростов-на-Дону, masterprint.proИнформационные технологии, системная интеграция, интернет... Показать ещеГрафический дизайнерРазработка макетов баннеров, листовок, визиток и прочей полиграфической продукции и последующий препресс. Разработка и визуализация наружной рекламы (вывески,стенды, таблички и пр.) Разработка фирменных стилей и логотипов. Работа над автоматизацией производственных процессов.', 'Октябрь 2010 — Май 20121 год 8 месяцев', 'РА "Статус"Каменск-Шахтинский, rastatus.ruСМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещестарший-менеджер дизайнерРазработка рекламной полиграфической, сувенирной продукции, ведение документации.', 'Декабрь 2007 — Октябрь 20102 года 11 месяцев', 'РА "Мастер Лайт"Каменск-Шахтинский, мастерлайт.рфСМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеГрафический дизайнерРазработка различных рекламных макетов, расчёт материала по чертежам, консультирование заказчиков,контроль на всех стадиях работы над проектом.'], 'tags': ['Figma', 'UI', 'UX', 'Web-дизайн', 'Прототипирование', 'Проектирование пользовательских интерфейсов', 'Adobe After Effects', 'Adobe Photoshop', '3D-графика'], 'link': ''}
# {'id': '', 'gender': 'Male', 'age': '33 years', 'date_of_birth': '28 September 1990', 'about_me': 'I am writing to submit my resume to be considered for the open position of UI/UX designer. With extensive experience in designing and implementing  user interfaces, I am well suited to this position.\n\nCurrently I m UX/UI designer, I offer a proven ability to conduct creative analysis and design best-fit solutions for multi-faceted campaigns including user research, interactive design and experience strategy.\n\nAs a detail oriented individual with a passion for excellence, I am adept at listening to client’s needs, then analyzing and implementing the best designed solution.\n\nWith my diverse and successful background in UI and UX design, I am uniquely suited to make a big difference to the digital face of your organization.\n\nThank you in advance for your consideration, and I look forward to our conversation.\nSincerely,\nAlmaz Ysagaliev', 'education': ['Higher education (bachelor)2013Academy of ManagementManagement, Project Management'], 'language': ['LanguagesRussian — NativeEnglish — C1 — Advanced'], 'job_search_status': 'Considers offers', 'place_of_residence': 'Bishkek', 'moving': 'willing to relocate (Russia, Georgia)', 'business_trip': 'prepared for business trips', 'name': 'Senior UI/UX Дизайнер', 'salary': '', 'specialization_schedule': 'Specializations: Designer, artist Game designer Employment: full time, part time, project work Work schedule: full day, flexible schedule, remote working', 'experience_all_period': 'Work experience 4 years 5 months', 'experience': ['February 2023 — currently1 year 4 months', 'Optima BankBishkekUX/UI DesignerСоздание дизайн системы я и постоянное обновление, чтобы она соответствовала требованиям проекта.\nВнедрение автоматизированного тестирование компонентов пользовательского интерфейса, чтобы гарантировать их соответствие стандартам дизайна и функциональности.\nВыступать  в качестве связующего звена между командами дизайнеров и разработчиков, обеспечивая точное воплощение принципов проектирования в коде.\nПроведение семинаров и тренингов для ознакомления членов команды с компонентами системы проектирования и лучшими практиками.\nРегулярное информирование заинтересованных сторон о состоянии системы проектирования, любых внесенных изменениях и о том, как это влияет на проекты.', 'January 2021 — October 20221 year 10 months', 'BTS DigitalAstanaIT, System Integration, Internet... Show moreUX/UI DesignerGathering and evaluating user requirements, in collaboration with product managers and engineers\nIllustrating design ideas using storyboards, process flows and sitemaps\nDesigning graphic user interface elements, like menus, tabs and widgets', 'January 2019 — March 20201 year 3 months', 'Evo MediaSaint PetersburgMedia, Marketing, Advertising, PR, Design, Production... Show moreUX/UI DesignerUnderstand product specifications and user psychology\nConduct concept and usability testing and gather feedback\nCreate personas through user research and data\nDefine the right interaction model and evaluate its success\nDevelop wireframes and prototypes around customer needs'], 'tags': ['User Experience', 'User Interface', 'Web Design', 'UI', 'Дизайн интерфейсов', 'Adobe Photoshop', 'Adobe Illustrator', 'UX'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '26 лет', 'date_of_birth': '20 февраля 1998', 'about_me': 'Я UX/UI дизайнер с опытом более 3-х лет. Умею разрабатывать креативные и функциональные дизайны приложений, многостраничных сайтов и лендингов начиная с проектирования resech и user flow заканчивая запуском проекта и его последующим улучшением\n\nHard skills:\nFigma (Работаю с компонентами, автолейаутами, вариантами, кликабельными прототипами)\nIllustrator   \nPhotoshop   \nTilda           \nBlender       \nAfter Effects. \nHTML           \nProtoPie        \nJira                \n\nSoft Skills:\nАналитические навыки\nПедантичность\nОтветственность \nЛидерские качества\nУмение работать в команде\nЖелание учиться \nВысокая обучаемость\n\nЯ мечтаю работать в классной и большой компании, расти и развиваться вместе\n\nПрофиль на Behance \nhttps://www.behance.net/guseva11351a8d', 'education': ['Высшее образование2020Донбасская национальная академия строительства и архитектуры, МакеевкаАрхитектурный , Архитектура'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — СреднийУкраинский — C2 — В совершенстве'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва, м. Белорусская', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'Senior UI/UX designer', 'salary': '300000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Другое Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 10 месяцев', 'experience': ['Август 2023 — по настоящее время10 месяцев', 'Т1МоскваUX/UI designerРазработка и развитие UI-Kit и Design System\nСоздание кликабельных прототипов\nРазработка сложных систем, веб-сайтов и приложений\nДоработка дизайна действующих продуктов компании\nФормулировка и проверка гипотез с помощью аналитики и UX-тестов\nВзаимодействие с менеджерами, аналитиками и командой разработки\nВзаимодействие с крупными заказчиками ', 'Декабрь 2022 — Январь 20241 год 2 месяца', 'ГРАН SoftwareМоскваИнформационные технологии, системная интеграция, интернет... Показать ещеUX/UI DesignerРазработка прототипов\nРазработка дизайн систем\nРазработка UI для сайтов и приложений\nРазработка рекламной продукции, дизайн соц. сетей\nРазработка и развитие UI-Kit и Design System\nФормулировка и проверка гипотез с помощью аналитики и UX-тестов\nВзаимодействие с менеджерами', 'Ноябрь 2021 — Декабрь 20221 год 2 месяца', 'AirGap StudioСанкт-ПетербургUX/UI designerСоздание user flow\nРазработка прототипов\nРазработка дизайн систем\nРазработка UI для сайтов и приложений\nРазработка рекламной продукции, дизайн соц. сетей\nВзаимодействие с менеджерами', 'Март 2021 — Ноябрь 20219 месяцев', 'Студия дизайна SeaIdeasДонецкUX/UI designerСоздание user flow\nРазработка прототипов\nРазработка дизайн систем\nРазработка UI для сайтов и приложений\nРазработка рекламной продукции, дизайн соц. сетей\nРабота с 3D (Blender)\nВзаимодействие с менеджерами', 'Август 2020 — Март 20218 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансГрафический дизайнерРазработка фирменных стилей \nРазработка 3D\nСоздание печатных материалов \nСоздание иллюстраций '], 'tags': ['Figma', 'Adobe After Effect', 'Adobe Photoshop', 'Adobe Illustrator', 'Procreate', 'Blender 3D', 'UX', 'UI', 'Web-дизайн', 'Стрессоустойчивость', 'Работа в команде', 'Design', 'HTML', 'Tilda', 'Дизайн интерфейсов'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '28 лет', 'date_of_birth': '31 мая 1995', 'about_me': 'Behance – behance.net/andryevs', 'education': ['Среднее специальное образование2013Санкт-Петербургский государственный университет, Санкт-ПетербургБакалавр , Бухгалтерский учет, анализ и аудит (экономист)'], 'language': ['Знание языковРусский — РоднойАнглийский — A2 — Элементарный'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Санкт-Петербург', 'moving': 'готов к переезду (Москва)', 'business_trip': 'не готов к командировкам', 'name': 'Web-Designer UX/UI', 'salary': '90000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, проектная работа, стажировка График работы: полный день', 'experience_all_period': 'Опыт работы 3 года 2 месяца', 'experience': ['Октябрь 2021 — по настоящее время2 года 8 месяцев', 'Lucky GroupUX/UI DesignerРазрабатывал и создавал главные веб-сайты для этих проектов и работал над улучшнием этих проектов, в будущем.\n\n◆ Аналитика, и использование данных для решения  существующих  задач их потребностей.\n◆ Создание продуманных  UI - KIT систем, для внутренних интерфейсов продукта.\n◆ Слаженная работа в команде внутри дизайн команды вместе с progect-менеджерами\n◆ Систематизация работы с проектами по системе MVP, \n◆ Работа с разработчиками', 'Сентябрь 2019 — Февраль 20206 месяцев', 'AODMWeb-дизайнерРазработки полного цикла веб-сайтов, общение с клиентами и защита проектов, создание банеров'], 'tags': ['UX', 'UI', 'Web Design', 'Проектирование пользовательских интерфейсов', 'Прототипирование', 'figma', 'Adobe After Effect', 'Mind Map', 'Wireframe', 'Дизайн интерфейсов', 'Веб-дизайн'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '29 лет', 'date_of_birth': '27 сентября 1994', 'about_me': '🎨 Фокус в дизайне: \nВеб-сайты • Веб-сервисы • iOS Apps • Android Apps\n\n🪄 Владение программами: \nFigma • Adobe Photoshop • Illustrator • Miro • Google Docs • Google Sheets\n\n• Проектирование UX исследований и анализа\n• Оценка проекта, времени и написание ТЗ\n• Опыт работы в большой команде\n• Наличие дополнительного образования в области UX/UI, web, графического дизайна и 2D рисования.\nЯ постоянно учусь и совершенствуюсь \n\n📔 Портфолио: https://www.behance.net/vicgladkih28c3', 'education': ['Высшее образование2019Белгородский государственный технологический университет им. В.Г. Шухова, БелгородАрхитектурно-строительный институт, Архитектура и градостроительство (магистр)2017Белгородский государственный технологический университет им. В.Г. Шухова, БелгородАрхитектурно-строительный институт, Архитектура и градостроительство (бакалавр)'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Белгород', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'UX/UI Designer', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 5 лет 4 месяца', 'experience': ['Июнь 2021 — по настоящее время3 года', 'WIM AgencyМосква, wim.agency/СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеWeb Designer• Проектирование лендингов\n• Разработка email-рассылкок\n• Проектирование баннеров, Push, Shortcut, Fullscreen и разных рекламных коммуникаций\n• Создание креативов для маркетинга\n• Работа с UI-Kit, дизайн-системой и библиотеками \n•  Проектирование тендерных презентаций для клиентов\n•  Разработка контекстной рекламы и поддержание сайта\n•  Работа в большой команде (включая взаимодействие с программистами и менеджерами)', 'Ноябрь 2022 — Декабрь 20231 год 2 месяца', 'UPROCKwww.uprock.ru/UX/UI Designer• Проведение аналитики и исследований (UX) \n- Сделала анализ персон, JTBD, User Flow, CJM, провела исследование аудитории\n- Провела функциональный, конкурентный и сводный анализ\n- Спроектировала информационную архитектуру \nи структуру приложения\n- Сделала функциональные и интерактивные прототипы\n\n• Создание и прорисовка мобильных интерфейсов для iOS и Android приложений и web сервиса\n- Разработка и поддержание UI KIT и дизайн системы\n\nДостижение:\n- Разработала 210+ экранов (для светлой и темной темы)\n- Написала спецификацию для разработчиков\n- Сделала адаптацию для Android, WEB и промо-лендинг', 'Февраль 2019 — Июнь 20212 года 5 месяцев', 'Cox CodeАвстралия, coxcode.io/Информационные технологии, системная интеграция, интернет... Показать ещеWeb-дизайнер• Проводила UX-исследования\n• Проектировала кликабельные прототипы\n• Создавала классные и удобные лендинги и web сайты\n• Работала в команде из 6 человек\n• Работала с графикой \n• Разрабатывала фирменный стиль\n• Разрабатывала печатную продукцию\n• Контроль качества реализации интерфейсов разработчиками', 'Май 2021 — Май 20211 месяц', 'Vintageboost.dsgnline.ru/Стажер UI/UX дизайнер• Разработала смысловую структуру главной страницы сайта жилого комплекса\n• Спроектировала промо лендинг\n• Прокачала концепт в несколько интеграций\n• Спроектировала мобильную версию', 'Март 2021 — Апрель 20212 месяца', 'UNIT9Великобритания, www.unit9.com/Web designer• Создавала питч-презентации\n• Разрабатывала дизайн билбордов, карт, постеров, сторис, почтовых открыток и других графических материалов\n• Работала в большой команде', 'Май 2020 — Июнь 20202 месяца', 'Humbleteam, CreativePeopleМосква, boost.dsgnline.ru/Стажер• Спроектировала виджет для приложения «Московский паркинг» на Android. \n• Составила микро-сценарий для сервиса совместных подарков. \n• Спроектировала решения интерфейса смены дня и ночи, а также времен года. \n• Спро ...
# ...
# {'id': '', 'gender': 'Мужчина', 'age': '25 лет', 'date_of_birth': '14 октября 1998', 'about_me': 'Меня зовут Илья и я продуктовый дизайнер уже 3 года.\nЗа это время работал на многих проектах, в том числе и зарубежных.\nПроектирую сложные user friendly системы, создаю B2B & BSS продукты, провожу тестирования, осуществляю редизайн готовых продуктов, занимаюсь анализом и исследованиями, разрабатываю компоненты для дизайн-системы и занимаюсь ее развитием, контролирую и проверяю fronted разработку продуктов и реализацию библиотеки,разрабатываю интерактивные прототипы и презентую продукт заказчику, взаимодействую с разработкой на протяжении всего жизненного цикла продукта.\nЛюблю красивый UI и понятный UX, развиваю хард и софт скиллы.\nПишите мне на почту указанную в анкете или в телеграмм по указанному номеру телефона, расскажу про свой опыт подробнее и покажу его на макетах )\n\nСсылка на превью работ \n\nhttps://www.figma.com/file/mkYRpJWuA3RAyWimCUCJUK/Markin-Portfolio?type=design&node-id=0%3A1&mode=design&t=O3OCQKuk8R2NRKhX-1', 'education': ['Высшее образование (Бакалавр)2020Нижегородский государственный технический университет им. Р.Е. Алексеева, Нижний НовгородИРИТ, Информационные системы и технологии в сфере дизайна'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Не\xa0ищет работу', 'place_of_residence': 'Нижний Новгород', 'moving': 'не готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Продуктовый дизайнер', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 4 года', 'experience': ['Октябрь 2022 — по настоящее время1 год 8 месяцев', 'InfowiseSenior UI/UX дизайнер / Продуктовый дизайнерСоздание и доработка web-приложений.\nРазработка внутренних продуктов и редизайн имеющихся систем. \nПроектирование пользовательских сценариев взаимодействия с продуктом, генерирование дизайн-решений и гипотез, отрисовка и проработка дизайн макетов и графических элементов, анимация.\nСоздание кликабельных прототипов и презентация заказчику.\nВзаимодействие с разработчиками продукта на этапе интеграции интерфейсных решений.\nВзаимодействие с заказчиками и проведение A/B тестов на всех этапах жизненного цикла продукта, разработки MVP. \nСоздание и поддержка дизайн системы, проверка реализации библиотеки и систем, проверка fronted-разработки.', 'Июнь 2021 — Сентябрь 20221 год 4 месяца', 'NetCracker Technology Corp. (Россия)www.netcracker.comИнформационные технологии, системная интеграция, интернет... Показать ещеUI/UX Designer Проведение анализа и research, работа с кейсами, проектирование систем, разработка B2B, BSS и внутренних продуктов, создание UI китов, отрисовка иконок, работа в PSUP', 'Июнь 2020 — Май 20211 год', 'Freelance UI/UX DesignerДизайн-системы, интерфейсы, исследования, Ui-кит, составление кейсов и анализ'], 'tags': ['UX', 'UI', 'Дизайн интерфейсов', 'Figma', 'B2C исследования', 'b2b исследования', 'Research', 'Прототипирование', 'Анализ', 'Анимация', 'Интерактивный дизайн', 'Human Interface Guidelines', 'UI Kit', 'User Flow', 'UI/UX', 'Тестирование пользовательского интерфейса', 'Проектирование пользовательских интерфейсов', 'Проектирование взаимодействия', 'CJM', 'UX-исследования', 'Usability', 'Usability Testing', 'Атомарный дизайн', 'Material Design', 'Дизайн мобильных приложений', 'Адаптивный дизайн'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '33 года', 'date_of_birth': '18 августа 1990', 'about_me': 'Ежедневно слежу за трендами и осмысленно применяю на практике. Полна идей и способна предлагать несколько  вариантов решения задачи. \nПолностью погружаюсь в процесс. \nБыстро и легко обучаюсь новому.\xa0\nВладею навыками и использую в работе нейросети.\nВ свободное время занимаюсь фото и видео съемкой.\n\nЧто умею?\n\n- Дизайн сайтов/лендингов (карточки товаров, формы)\n- Адаптивы для разных разрешений экрана\n- Прототип\n- Анимация сайта\xa0 (Figma, AE)\n- Дизайн постеров и баннеров\n- Монтаж видео и создание эффектов\n\n\nВладею программами:\n\n- Figma\n- Tilda\n- Illustrator\n- Photoshop\n- InDesign\n- AfterEffects\n- Premier pro\n- Midjourney\n\n\nБыла наставником курсов по web-дизайну, типографики и композиции и адаптивному дизайну на платформе GeekBrains.\n\nМоё портфолио - https://www.behance.net/jull_kot', 'education': ['Высшее образование2021GeekBrains UniversityДизайн  (Фуллстек), Веб-дизайнер, UX/UI дизайнер, продуктовый дизайнер, графический дизайнер, дизайнер интерфейсов2015Финансовый университет при Правительстве Российской Федерации, МоскваФинансы и кредит, Экономист2008Технологический колледж №34Конструирование швейных изделий, Модельер-конструктор'], 'language': ['Знание языковРусский — РоднойАнглийский — A2 — Элементарный'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Москва', 'moving': 'не готова к переезду', 'business_trip': 'готова к редким командировкам', 'name': 'Web-дизайнер/Графический дизайнер', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 2 месяца', 'experience': ['Июнь 2023 — по настоящее время1 год', 'Самолет Девелопмент бренд медиа «Проще говоря»Москва, samoletgroup.ruСтроительство, недвижимость, эксплуатация, проектирование... Показать ещеСтарший дизайнер Запуск нового медиа, редакционный дизайн выпуска, разработка гайдов для сайта и соцсетей', 'Апрель 2021 — по настоящее время3 года 2 месяца', 'Индивидуальное предпринимательство / частная практика / фрилансWeb-дизайнер, Графический дизайнерЛендинг, веб сайт, брендирование, логотипы, афиши, дизайн социальных сетей', 'Август 2021 — Февраль 20231 год 7 месяцев', 'The Village  ООО "Креатив Медиа" ДизайнерВерстка статей, создание банеров, работа с гайдлайнами, разработка шаблонов обложек для социальных сетей и  видео формата, ведение др. проектов.', 'Май 2022 — Август 20224 месяца', 'Городской интернет-сайт "Большой город"ДизайнерДизайнер выпуска, верстка статей, создание визуала для социальных сетей и разработка шаблонов'], 'tags': ['Адаптивный дизайн', 'Figma', 'Tilda', 'Web-дизайн', 'Прототипирование', 'Графический дизайн', 'Adobe Illustrator', 'Adobe Premier Pro', 'Видеомонтаж', 'Adobe After Effect', 'Фотография', 'Видеосъемка', 'UX', 'UI', 'Adobe Lightroom', 'Adobe Photoshop', 'Работа в команде', 'Креативность'], 'link': ''}
# {'id': '', 'gender': 'Женщина', 'age': '28 лет', 'date_of_birth': '15 сентября 1995', 'about_me': 'Хорошие продажи , лидерские качества , весёлая энергичная жизнерадостная\n\nhttps://www.behance.net/4696c45c', 'education': ['Среднее специальное образование2017Педагогический колледж им Гагарина Саратов Тмс , Технология машиностроения'], 'language': ['Знание языковРусский — РоднойАнглийский — A1 — Начальный'], 'job_search_status': 'Предложили работу, решает', 'place_of_residence': 'Москва, м. Домодедовская', 'moving': 'готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'Дизайнер', 'salary': '60000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Менеджер по продажам, менеджер по работе с клиентами Менеджер по работе с партнерами Торговый представитель Продавец-консультант, продавец-кассир Занятость: полная занятость, частичная занятость График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 7 месяцев', 'experience': ['Март 2024 — по настоящее время3 месяца', 'ФрилансWeb-дизайнерРазработка десктопных и мобильных приложений, лендинги. Анализ конкурентов, карта клика', 'Май 2017 — Июль 20181 год 3 месяца', 'КАРИСаратов, www.kari.comРозничная торговля... Показать ещеАдминистратор магазина Целеустремлённая , нацеленная на результат , стрессоустойчивая', 'Ноябрь 2016 — Апрель 20176 месяцев', 'КАРИСаратов, www.kari.comРозничная торговля... Показать ещеПродавец-консультантХорошие продажи одна из списка лидирующих продавцов в этом  магазине ', 'Май 2016 — Август 20164 месяца', 'Кристалл Саратов СаратовПродавец-кассир Продажа ювелирных изделий сортировка ', 'Март 2015 — Август 20156 месяцев', 'Невские ломбарды  585Санкт-ПетербургПродавец-консультантПродажа ювелирных изделий ,  товаровед ', 'Август 2014 — Январь 20156 месяцев', 'АквариусСаратовПродавец-консультантПродажа аксессуаров , продажа обуви , продажи одежды ', 'Июль 2014 — Август 20142 месяца', 'Маяк СаратовВожатый  Следить за детьми , обучать , проводить конкурсы ', 'Октябрь 2013 — Ноябрь 20132 месяца', 'Ип Распутин , рубль бум СаратовМенеджер  Работа в зале , сортировка правила мерчандайзинга '], 'tags': ['Web-дизайн'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '31 год', 'date_of_birth': '19 октября 1992', 'about_me': '', 'education': ['ОбразованиеСреднее образование'], 'language': ['Знание языковЯкутский — РоднойАнглийский — A2 — ЭлементарныйРусский — C2 — В совершенстве'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Калининград', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Продуктовый дизайнер (Дизайн-система)', 'salary': '', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 11 лет 2 месяца', 'experience': ['Апрель 2023 — по настоящее время1 год 2 месяца', 'Cloud.ruПродуктовый дизайнер дизайн-системы- Разработка и доработка компонентов;\n- Проектирование системы токенов;\n- Написание документации;\n- Проведение ревью;\n- Регулярное общение с разработчиками.', 'Ноябрь 2020 — Февраль 20232 года 4 месяца', 'ООО Ак Барс Цифровые ТехнологииКазань, akbars.digitalПродуктовый дизайнер- Работа в продуктовой команде;\n- Создание и развитие дизайн-системы;\n- Проектирование интерфейсов;\n- Создание кликабельных прототипов для проверки гипотез;\n- Проведение исследований и улучшение пользовательских сценариев;', 'Май 2016 — Май 20193 года 1 месяц', 'ООО "Платформа"UX/UI дизайнер- Проектирование и дизайн веб-интерфейсов, сайтов, приложений;\n- Сдача и защита проекта перед заказчиком;\n- Дизайн посадочных страниц;', 'Май 2015 — Май 20161 год 1 месяц', 'Вооруженные силы РФmil.ru/Командир-отделенияРуководство отделением автомобильного взвода', 'Июль 2012 — Май 20152 года 11 месяцев', 'ООО "МГ Реакция"Веб-дизайнерПроектирование и дизайн веб-сайтов, приложений.', 'Октябрь 2011 — Июнь 20129 месяцев', 'ООО "ГК Синет"Помощник арт-директораПроектирование и дизайн веб-сайтов'], 'tags': ['UX', 'UI', ' HTML', 'CSS', 'Проектирование пользовательских интерфейсов', 'Дизайн интерфейсов', 'Веб-дизайн', 'Управление проектами', 'Графический дизайн', 'Ведение переговоров', 'Управление персоналом', 'Adobe Photoshop', 'Sketch', 'Figma', 'Zeplin', 'CorelDRAW', 'Adobe XD', 'Principle', 'Atlassian Jira', 'Atlassian Confluence', 'Pixso', 'Scrum', 'Прототипирование', 'Agile', 'Material Design', 'Адаптивный дизайн', 'Web-дизайн', 'Дизайн мобильных приложений', 'UI Kit'], 'link': ''}
# {'id': '', 'gender': 'Мужчина', 'age': '32 года', 'date_of_birth': '1 сентября 1991', 'about_me': 'Привет, меня зовут — Евгений. \nАрт-директор для B2B, B2C компаний и сервисов.\n\nВ качестве штатного арт-директора и внешнего консультанта более 12 лет помогаю компаниям создавать и развивать онлайн-сервисы и приложения. Люблю разрабатывать и оптимизировать дизайн-процессы. Собирать и направлять команду под дизайн-задачи. Выстраивать отношения между дизайнерами, аналитиками, фронтами, беками и продактами.\n\nБольшой опыт работы в продуктовых командах, в иностранных стартапах, руководил дизайнерами, демонстрировал результаты работы акционерам и замминистров.\n\nУмею работать в рамках технических ограничений и в поле неопределоённости. Умею ставить задачи и контролировать их выполнение.\n\nИщу удалённую работу в крупных проектах, где нужно свести дизайн, пользу для людей и выгоду для компании в единую систему и вывести всё это на новый уровень.\n\n\nДОСТИЖЕНИЯ\n\n- Открывал веб-студии, собирал команды, запускал собственные проекты.\n\n- Работал с Билайн, УГМК, Mebelstol, Цезарь Сателлит, Слетать.ру и другими серьёзными компаниями.\n\n- Работал с крупными интеграторами BPC и БСТ.\n\n- Создал дизайн Callibri и Gudok.tel.\n\n- 2 года успешно работал Lead Designer американского стартапа по поиску работы и вакансий Doostang.\n\n- Разрабатывал проект крупной компании для выставки Иннопром.\n\n- Успешный профиль с отзывами на Upwork. Работал с иностранными рынками.\n\ndesign[at]elikov.ru\nTg: @elikov\n\n\n_', 'education': ['Высшее образование2002Уральский федеральный университет имени первого Президента России Б.Н. Ельцина, ЕкатеринбургМенеджер по управлению проектами, Маркетолог, диплом1999ЕКТСОтделение передовых информационных технологий, Техник-программист'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Предложили работу, решает', 'place_of_residence': 'Екатеринбург', 'moving': 'не готов к переезду', 'business_trip': 'готов к редким командировкам', 'name': 'Арт-директор, внешний дизайн-консультант', 'salary': '600000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Менеджер продукта Арт-директор, креативный директор Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 22 года 9 месяцев', 'experience': ['Сентябрь 2020 — по настоящее время3 года 9 месяцев', 'Группа компаний «БПЦ»Екатеринбург, www.bpcgroup.ruИнформационные технологии, системная интеграция, интернет... Показать ещеMarketplace Department Design Team LeadПровёл комплексный редизайн международного маркетплейса, кабинета продавца, системы управления маркетплейсом и мобильного приложения.\n\nСобрал команду дизайнеров. Ставлю задачи, контролирую исполнение, занимаюсь менторством джуниоров.', 'Сентябрь 2001 — по настоящее время22 года 9 месяцев', 'Elikov.ruelikov.ruИнформационные технологии, системная интеграция, интернет... Показать ещеDigital-продюсерПроектирование, дизайн и консалтинг digital-продуктов для самых разных сфер. Финансовые системы, туристические, сервисные, производственные, образовательные.\r\n\r\nМенеджмент проектов, подбор команды на проекты, взаимодействие с инвесторами. Контроль достижения результатов.', 'Ноябрь 2021 — Сентябрь 202211 месяцев', 'Бизнес Система Телеком, ОООМосква, www.bstelecom.ruИнформационные технологии, системная интеграция, интернет... Показать ещеВедущий UX/UI дизайнерОтвечал за разработку дизайна государственной информационной системы.\n\nРуководил отделом дизайна. Взаимодействовал с аналитиками, менеджерами, представителями заказчика.', 'Февраль 2017 — Январь 20181 год', 'Strekoza.travelstrekoza.travelИнформационные технологии, системная интеграция, интернет... Показать ещеUI/UX Design Lead, дизайнер продуктаКак дизайнер продукта я отвечал за развитие идей инвесторов, аналитику потребностей пользователей и соответствие бизнес-целям.\r\n\r\nВ качестве ведущего проектировщика и UI-дизайнера занимался реинж ...

# %%
def count_lines_in_file_efficient(file_path):
    count = 0
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            count += 1
    return count

line_count = count_lines_in_file_efficient(f'/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv')
print(f'Количество строк в файле: {line_count}')
# Out:
# Количество строк в файле: 21039

# %%
# Извлекаем информацию из файла с парсингом резюме при помощи pandas
data_res_resume = pd.read_csv(f'/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv')

# %%
data_res_resume
# Out:
#       id   gender      age    date_of_birth  \
# 0    NaN  Мужчина   21 год  15 октября 2002
# 1    NaN  Мужчина   39 лет  25 августа 1984
# 2    NaN  Мужчина   38 лет   10 января 1986
# 3    NaN  Мужчина  42 года     20 июня 1981
# 4    NaN  Женщина   38 лет   4 февраля 1986
# ...   ..      ...      ...              ...
# 4779 NaN  Мужчина   45 лет      15 мая 1978
# 4780 NaN  Мужчина  42 года  23 февраля 1982
# 4781 NaN  Женщина   50 лет   29 января 1974
# 4782 NaN  Женщина   25 лет  20 октября 1998
# 4783 NaN  Женщина  33 года   30 апреля 1991
#
#                                                about_me  \
# 0     Исполнительный, ответственный, быстро обучаемы...
# 1     Чтение профессиональной и художественной литер...
# 2     Могу охарактеризовать себя, как ответственного...
# 3     Большой опыт студийной сьемки, свадебной сьемк...
# 4                                                   NaN
# ...                                                 ...
# 4779  «пунктуальность», «работоспособность», «органи...
# 4780  ПРОФЕССИОНАЛЬНЫЕ НАВЫКИ И ЗНАНИЯ\n-\tWindows, ...
# 4781  Ответственность, внимательность, обучаемость. ...
# 4782  Имею высшее образование по специальности "Прав...
# 4783  Пунктуальность, честность, доброта, коммуникаб...
#
#                                               education  \
# 0     ['Неоконченное высшее образование2027Российски...
# 1     ['Высшее образование2024Учетный центр «ПромРес...
# 2     ['Высшее образование2010Национальный авиационн...
# 3     ['Высшее образование2010Российский государстве...
# 4     ['Высшее образование2016Елецкий государственны...
# ...                                                 ...
# 4779  ['Высшее образование2013Московский автомобильн...
# 4780  ['Высшее образование2022ООО «Академия професси...
# 4781  ['Среднее специальное образование1992ПТУ #114С...
# 4782  ['Высшее образование2021Гомельский государстве...
# 4783  ['Высшее образование2014Тюменский государствен...
#
#                                                language  \
# 0                     ['Знание языковРусский — Родной']
# 1                     ['Знание языковРусский — Родной']
# 2     ['Знание языковРусский — РоднойАнглийский — C1...
# 3     ['Знание языковРусский — РоднойАнглийский — A1...
# 4     ['Знание языковРусский — РоднойАнглийский — A1...
# ...                                                 ...
# 4779                  ['Знание языковРусский — Родной']
# 4780  ['Знание языковРусский — РоднойАнглийский — A1...
# 4781                  ['Знание языковРусский — Родной']
# 4782                  ['Знание языковРусский — Родной']
# 4783  ['Знание языковРусский — РоднойАнглийский — A1...
#
#               job_search_status      place_of_residence  \
# 0                Не ищет работу                  Москва
# 1           Активно ищет работу                     Буй
# 2     Рассматривает предложения  Москва, м. Рассказовка
# 3           Активно ищет работу             Красногорск
# 4           Активно ищет работу                  Москва
# ...                         ...                     ...
# 4779        Активно ищет работу                  Москва
# 4780        Активно ищет работу               Краснодар
# 4781  Рассматривает предложения    Москва, м. Зябликово
# 4782  Рассматривает предложения                 Наровля
# 4783             Не ищет работу                  Тюмень
#
#                                   moving                 business_trip  \
# 0                    не готов к переезду         готов к командировкам
# 1                    не готов к переезду         готов к командировкам
# 2                    не готов к переезду         готов к командировкам
# 3                       готов к переезду  готов к редким командировкам
# 4                   не готова к переезду     не готова к командировкам
# ...                                  ...                           ...
# 4779                 не готов к переезду         готов к командировкам
# 4780                 не готов к переезду         готов к командировкам
# 4781                не готова к переезду     не готова к командировкам
# 4782  готова к переезду (Гомель, Мозырь)        готова к командировкам
# 4783                не готова к переезду     не готова к командировкам
#
#                                                    name            salary  \
# 0                               Системный администратор  120000 ₽ на руки
# 1                                 Заведующий склада ГСМ               NaN
# 2     Главный специалист, Ведущий специалист, Специа...               NaN
# 3                                              Фотограф               NaN
# 4     Психолог детский, медицинская сестра, продавец...  100000 ₽ на руки
# ...                                                 ...               ...
# 4779                              Начальник автоколонны               NaN
# 4780  Начальник участка (цеха)/Начальник производств...  180000 ₽ на руки
# 4781                               Оператор базы данных   30000 ₽ на руки
# 4782                 Юрисконсульт, специалист по кадрам               NaN
# 4783                                        Инженер ПТО  100000 ₽ на руки
#
#                                 specialization_schedule  \
# 0     Специализации: Системный администратор Dev Ops...
# 1     Специализации: Другое Прораб, мастер  С М Р На...
# 2     Специализации: Другое Занятость: полная занято...
# 3     Специализации: Фотограф, ретушер Занятость: по...
# 4     Специализации: Психолог Секретарь, помощник ру...
# ...                                                 ...
# 4779  Специализации: Сервисный инженер, инженер-меха...
# 4780  Специализации: Менеджер по закупкам Специалист...
# 4781  Специализации: Оператор  П К, оператор базы да...
# 4782  Специализации: Юрисконсульт Юрист Занятость: п...
# 4783  Специализации: Инженер  П Т О, инженер-сметчик...
#
#              experience_all_period  \
# 0      Опыт работы 3 года 2 месяца
# 1     Опыт работы 20 лет 8 месяцев
# 2     Опыт работы 12 лет 8 месяцев
# 3      Опыт работы 16 лет 3 месяца
# 4       Опыт работы 16 лет 1 месяц
# ...                            ...
# 4779   Опыт работы 28 лет 3 месяца
# 4780    Опыт работы 18 лет 1 месяц
# 4781  Опыт работы 19 лет 6 месяцев
# 4782  Опыт работы 6 лет 10 месяцев
# 4783  Опыт работы 13 лет 9 месяцев
#
#                                              experience  \
# 0     ['Декабрь 2023 — по настоящее время6 месяцев',...
# 1     ['Октябрь 2019 — по настоящее время4 года 8 ме...
# 2     ['Август 2022 — по настоящее время1 год 10 мес...
# 3     ['Октябрь 2014 — по настоящее время9 лет 8 мес...
# 4     ['Август 2017 — по настоящее время6 лет 10 мес...
# ...                                                 ...
# 4779  ['Январь 2018 — по настоящее время6 лет 5 меся...
# 4780  ['Октябрь 2023 — по настоящее время8 месяцев',...
# 4781  ['Ноябрь 1996 — Сентябрь 201518 лет 11 месяцев...
# 4782  ['Декабрь 2018 — по настоящее время5 лет 6 мес...
# 4783  ['Август 2019 — Апрель 20244 года 9 месяцев', ...
#
#                                                    tags  link
# 0     ['Linux', 'WMware', 'VirtualBox', 'Zabbix', 'M...   NaN
# 1     ['Ответственность', 'Работа с оргтехникой', 'П...   NaN
# 2     ['MC Office, Power Point, Excell', 'SITA, Gabr...   NaN
# 3     ['Фотография', 'Adobe Photoshop', 'Репортажная...   NaN
# 4     ['Общая психология', 'Детская психология', 'По...   NaN
# ...                                                 ...   ...
# 4779  ['Компания Такси (Таксопарк): Основным принцип...   NaN
# 4780                   ['НАКС III уровень (охвнп, ск)']   NaN
# 4781  ['Пользователь ПК', 'Работа с базами данных', ...   NaN
# 4782  ['Администрирование приема, перевода и увольне...   NaN
# 4783  ['MS Word', 'Google Chrome', '1С: Предприятие ...   NaN
#
# [4784 rows x 18 columns]
