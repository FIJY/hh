# %% [markdown]
# <a href="https://colab.research.google.com/github/FIJY/hh/blob/master/%D0%9F%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3_hh_(%D1%80%D0%B5%D0%B7%D1%83%D0%BB%D1%8C%D1%82%D0%B8%D1%80_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Парсинг с сайта hh <br>
# Ссылка на видео парсинга hh https://yandex.ru/video/preview/11468178118806870731

# %% [markdown]
# ## Устанавливаем и импортируем библиотеки и модули, подключаем гугл диск

# %%
# Устанавливаем библиотеки
# requests для отправки запросов
# BeautifulSoup для разбора полученных данных
# lxml для парсинга
# fake_useragent для создания заголовков
# !pip install requests (requests в colab можно не устанавливать)
# !pip install bs4
# !pip install lxml (lxml в colab можно не устанавливать)
# !pip install fake_useragent
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)

# %%
# Импортируем библиотеки
import requests
from bs4 import BeautifulSoup
import fake_useragent
import time
import json
import pandas as pd
import re
import csv
import os
from tqdm import tqdm

# %%
# Подключаем гугл диск
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Парсинг hh

# %% [markdown]
# ### Создание параметров поиска резюме, <br>получение ссылки-запроса для последующего парсинга ссылок резюме.  <br><br> Источник параметров поиска <br> https://github.com/EvgenyTerebenin/hh-api/blob/master/docs/resumes_search.md

# %%
# Функция создания ссылки для поиска резюме по заданным параметрам

def ref_search_resume (text: str, what_search = 'normal', list_search = ['full_text'],
                       sorting = 'relevance', date_period = 30, date_min = None,
                       date_max = None, quantity_items = 20, areas = [113],
                       arg_relocation = "living_or_relocation", exp_industry = None,
                       exp_period = 'all_time', job_search = None, age_min = None,
                       age_max = None, age_if = False, employments = None,
                       schedules = None, experiences = None, prof_roles = None,
                       gen = "unknown", gender_if = False, salary_min = None,
                       salary_max = None, currency = "RUB", salary_if = False,
                       countries = None, foto_if = False, vehicle_if = False,
                       educations = None, universities = None, ver_skills = None,
                       key_skills = None, work_countries = None,
                       driver_types = None, languages = None,
                       verif_languages = None):

  '''
  Функция создания ссылки для поиска резюме по заданным параметрам.

  :text: Слово или фраза для поиска резюме.

  :what_search = 'normal': Какие слова использовать в поиске
  "Все слова": normal,
  "Любое из слов": any,
  "Точная фраза": phrase,
  "Не встречаются": except

  :list_search = ['full_text']: Где искать указанные слова
  "Везде": full_text,
  "В названии резюме": position,
  "В образовании": education,
  "В ключевых навыках": keywords,
  "В опыте работы": workplaces
  При уточнении можно подавать несколько, списком, но не более трех,
  иначе будет вариант "Везде".

  :sorting = 'relevance': Способ сортировки списка резюме.
  "По дате изменения": publication_time,
  "По убыванию зарплат": salary_desc,
  "По возрастанию зарплаты": salary_asc,
  "По соответствию": relevance

  :date_period = 0: За какой период искать
  "За все время": 0,
  "За сутки": 1,
  "За последние три дня": 3,
  "За неделю": 7,
  "За месяц": 30,
  "За год": 365

  :date_min = None  date_max = None: Интервал поиска между датами
  Формат указания дат ДД.ММ.ГГГГ

  :quantity_items = 20: Количество резюме на одной странице
  Можно указывать любое количество. Стандартный выбор: 20, 50, 70, 100

  :areas = [113]: Регион поиска
  Можно выбирать несколько, подается список кодов регионов
  Источник https://api.hh.ru/areas
  Обозначения некоторых регионов:
  Россия: 113,
  Москва: 1, Московская область: 2019,
  Санкт-Петербург: 2, Ленинградская область: 145,
  Екатеринбург: 3, Свердловская область: 1261,
  Новосибирск: 4, Новосибирская область: 1202,
  Нижний Новгород: 66, Красноярск: 54, Челябинск: 104, Самара: 78, Уфа: 99,
  Краснодар: 53, Ростов-на-Дону: 76, Омск: 68, Воронеж: 26, Пермь: 72, Волгоград: 24,
  Татарстан: 1624, Казань: 88

  :arg_relocation = "living_or_relocation": Переезд
  Источник
  https://api.hh.ru/openapi/redoc#tag/Obshie-spravochniki/operation/get-dictionaries
  Варианты, подается один из вариантов:
  "living_or_relocation" - Живут в указанном регионе или готовы переехать в него,
  "living" - Живут в указанном регионе,
  "living_but_relocation" - Живут в указанном регионе и готовы к переезду куда-либо,
  "relocation" - "Не живут в указанном регионе, но готовы переехать в него"

  :exp_industry = None: Опыт работы в отрасли
  Указывается требуемая отрасль;
  По умолчанию выбраны все отрасли
  Можно выбирать несколько, подается списком кодов отраслей
  Источник https://api.hh.ru/industries
  "Информационные технологии, системная интеграция, интернет": "7",
  включает в себя:
  "Интернет-провайдер": "7.538",
  "Системная интеграция,  автоматизации технологических и
  бизнес-процессов предприятия, ИТ-консалтинг": "7.539",
  "Разработка программного обеспечения": "7.540",
  "Интернет-компания (поисковики, платежные системы, соц.сети,
  информационно-познавательные и развлекательные ресурсы,
  продвижение сайтов и прочее)": "7.541"

  :exp_period = 'all_time': Период работы в отрасли, указывается вместе с опытом работы
  Источник
  https://api.hh.ru/openapi/redoc#tag/Poisk-rezyume/operation/search-for-resumes
  Варианты, выбирается один из вариантов:
  "all_time" - за всё время работы;
  "last_year" - за последний год;
  "last_three_years" - за последние 3 года;
  "last_six_years" - за последние 6 лет

  :job_search = None: Статус поиска работы
  Варианты, можно выбирать несколько, подается списком:
  "unknown" - Без статуса поиска;
  "not_looking_for_job" - Не ищет работу;
  "looking_for_offers" - Рассматривает предложения;
  "active_search" - Активно ищет работу;
  "has_job_offer" - Предложили работу, решает;
  "accepted_job_offer" - Вышел на новое место

  :age_min = None  age_max = None: Возраст, от и до
  :age_if = False: Найти резюме только с возрастом
  (по умолчанию фильтр отсутствует)

  :employments = None: Тип занятости
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "full" - Полная занятость;
  "part" - Частичная занятость;
  "project" - Проектная работа;
  "probation" - Стажировка;
  "volunteer" - Волонтерство

  :schedules = None: График работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "fullDay" - Полный день;
  "remote" - Удаленная работа;
  "flexible" - Гибкий график;
  "shift" - Сменный график;
  "flyInFlyOut" - Вахтовый метод

  :experiences = None: Опыт работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "moreThan6" - Более 6 лет;
  "between3And6" - От 3 до 6 лет;
  "noExperience" - Нет опыта;
  "between1And3" - От 1 года до 3 лет

  :prof_roles = None: Специализации
  По умолчанию не указаны
  Перечень кодов специализаций (направление "Информационные технологии"),
  можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/professional_roles
  "BI-аналитик, аналитик данных": 156,
  "DevOps-инженер": 160,
  "Аналитик": 10,
  "Арт-директор, креативный директор": 12,
  "Бизнес-аналитик": 150,
  "Гейм-дизайнер": 25,
  "Дата-сайентист": 165,
  "Дизайнер, художник": 34,
  "Директор по информационным технологиям (CIO)": 36,
  "Менеджер продукта": 73,
  "Методолог": 155,
  "Программист, разработчик": 96,
  "Продуктовый аналитик": 164,
  "Руководитель группы разработки": 104,
  "Руководитель отдела аналитики": 157,
  "Руководитель проектов": 107,
  "Сетевой инженер": 112,
  "Системный администратор": 113,
  "Системный аналитик": 148,
  "Системный инженер": 114,
  "Специалист по информационной безопасности": 116,
  "Специалист технической поддержки": 121,
  "Тестировщик": 124,
  "Технический директор (CTO)": 125,
  "Технический писатель": 126,
  "Другое": 40

  :gen = "unknown": Пол
  "unknown" - не имеет значения;
  "male" - мужской;
  "female" - женский

  :gender_if = False: Показать резюме с указанием пола
  По умолчанию фильтр отсутствует

  :salary_min = None: Зарплата от
  :salary_max = None: Зарплата до
  :currency = "RUB": Валюта
  Можно задать в евро EUR или в долларах USD

  :salary_if = False: Показать резюме только где указан доход
  По умолчанию фильтр отсутствует

  :countries = None: Гражданство, страна
  Перечень некоторых кодов стран, можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :foto_if = False  vehicle_if = False: Есть фото, автомобиль
  По умолчанию фильтры отсутствуют

  :educations = None: Образование
  Перечень видов образования, можно выбирать несколько, подается список названий:
  "Среднее": secondary,
  "Среднее специальное": special_secondary,
  "Незаконченное высшее": unfinished_higher,
  "Бакалавр": bachelor,
  "Магистр": master,
  "Высшее": higher,
  "Кандидат наук": candidate,
  "Доктор наук": doctor

  :universities = None: Учебное заведение
  Перечень кодов некоторых учебных заведений, можно выбирать несколько,
  подается список кодов:
  Источник https://app.psal.ru/api/university/
  "МГУ": 39144,
  "Национальный исследовательский университет ИТМО": 39872,
  "НИЯУ МИФИ": 39650,
  "МГТУ им. Н.Э. Баумана": 38921

  :ver_skills = None: Подтвержденные навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  "Python": 1114,
  "MS Excel": 845,
  "SQL": 1252,
  "Git": 3215,
  "HTML": 598,
  "ООП": 2350,
  "JavaScript": 674,
  "Agile Project Management": 998,
  "Scrum": 3193,
  "Копирайтинг": 2097,
  "AutoCAD": 153

  :key_skills = None: Ключевые навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  'Python': 1114, 'SQL': 1252, 'Git': 3215, 'Linux': 730, 'Английский язык': 5488,
  'HTML': 598, 'MS Excel': 845, 'JavaScript': 674, 'Работа в команде': 4118,
  'MySQL': 893, 'PostgreSQL': 1063, 'MS PowerPoint': 866, 'C++': 231, 'CSS': 351,
  'Управление проектами': 2924, 'ООП': 2350, 'Пользователь ПК': 3864,
  'Adobe Photoshop': 87, 'Java': 3093, 'Организаторские навыки': 2366,
  'Грамотная речь': 1827, 'C#': 230, 'HTML5': 7161, 'Ведение переговоров': 1691,
  'PHP': 3750, 'Работа с большим объемом информации': 6958, 'C/C++': 144745,
  'MS Word': 883, 'Деловая переписка': 1855, 'Django Framework': 416,
  'Atlassian Jira': 142, 'Анализ данных': 1534, 'MS SQL': 871,
  'Аналитическое мышление': 14886, 'MATLAB': 791, 'Bash': 4070, 'CSS3': 3512,
  'Деловое общение': 1857, 'Математическая статистика': 2190, 'MS Outlook': 860,
  'AutoCAD': 153, 'Data Analysis': 372, 'jQuery': 687,
  'Управление персоналом': 2917, 'Scrum': 3193, 'Базы данных': 8540,
  'Работа с базами данных': 17049, 'Проведение презентаций': 2514,
  'Деловая коммуникация': 1853, 'Agile Project Management': 99

  :work_countries = None: Разрешение на работу, страна
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :driver_types = None: Категория прав
  Перечень категорий, можно выбирать несколько, подается список категорий:
  B, C, A, BE, D, E, CE, DE, Tm (трамвай), Tb (троллейбус)

  :languages = None: Знание языков, уровень
  Можно выбирать несколько, подается список языков
  Перечень некоторых языков:
  Источник https://api.hh.ru/languages
  "Русский": rus, 34;
  "Английский": eng, 57;
  "Французский": fra, 59;
  "Немецкий": deu, 58;
  "Белорусский": bel, 7;
  "Китайский": zho, 20
  С языком указывается уровень владения, например "eng.a1"
  Перечень уровней владения языком:
  a1 - Начальный, a2 - Элементарный,
  b1 - Средний, b2 - Средне-продвинутый,
  c1 - Продвинутый, c2 - В совершенстве,
  l1 - Родной язык

  :verif_languages = None: Подтвержденные знания
  (указываются только по английскому языку)
  Перечень кодов подтвержденных знаний:
  "a1 Начальный": 57.1;
  "a2 Элементарный": 57.2;
  "b1 Средний": 57.3;
  "b2 Средне-продвинутый": 57.4;
  "c1 Продвинутый": 57.5;
  "c2 В совершенстве": 57.6
  '''
  # Слово/фраза для поиска резюме
  # Перед подачей в url заменим в text пробелы и другие символы (,;) на url-коды
  text = text.replace(" ", "+").replace(",", "%2C").replace(";", "%3B")

  # Какие слова использовать в поиске
  # what_search = 'any'
  # what_search = 'phrase'
  # what_search = 'except'
  logic = f'&logic={what_search}'

  # Где искать указанные слова
  # list_search = ['keywords', 'position']
  # list_search = ['keywords', 'position', 'education', 'workplaces']
  # list_search = ['keywords']
  if (len(list_search) < 4):
    where_search = '%2C'.join(list_search)
  else:
    where_search = 'full_text'
  pos = f'&pos={where_search}'

  # Способ сортировки списка резюме
  # sorting = 'salary_desc'
  order_by = f'&order_by={sorting}'

  # За какой период искать
  # date_period = 30

  # Интервал поиска между датами
  # date_min = '01.03.2024'
  # date_max = '15.03.2024'
  if (date_min and date_max):
    search_period = f'&search_period=-1&date_from={date_min}&date_to={date_max}'
  else:
    search_period = f'&search_period={date_period}'

  # Количество резюме на одной странице
  # quantity_items = 5
  items_on_page = f'&items_on_page={quantity_items}'

  # Регион поиска
  # areas = [113, 4]
  area = ''.join(f'&area={region}' for region in areas)

  # Переезд
  # arg_relocation = "living"
  relocation = f'&relocation={arg_relocation}'

  # Опыт работы в отрасли
  # exp_industry = [7] # Подается списком кодов отраслей
  # exp_industry = [7.538, 7.540, 7.541]
  filter_exp_industry = ''
  if exp_industry:
    filter_exp_industry = ''.join(f'&filter_exp_industry={exp_industry:.3f}'
                                  if isinstance(exp_industry, float)
                                  else f'&filter_exp_industry={int(exp_industry)}'
                                  for exp_industry in exp_industry)

  # Период опыта работы в отрасли
  # exp_period = "last_year"
  filter_exp_period = f'&filter_exp_period={exp_period}'

  # Статус поиска работы
  # job_search = ["looking_for_offers", "has_job_offer"]
  job_search_status = ''
  if job_search:
    job_search_status = ''.join(f'&job_search_status={search}'
                                for search in job_search)

  # Возраст
  # age_min = 35
  # age_max = 45
  # age_if = True
  age_from = ''
  age_to = ''
  label_age = ''
  if age_min: age_from = f'&age_from={age_min}'
  if age_max: age_to = f'&age_to={age_max}'
  if age_if: label_age = f'&label=only_with_age'

  # Тип занятости
  # employments = ['part', 'probation']
  employment = ''
  if employments:
    employment = ''.join(f'&employment={empl}' for empl in employments)

  # График работы
  # schedules = ['remote', 'flexible']
  schedule = ''
  if schedules:
    schedule = ''.join(f'&schedule={sched}' for sched in schedules)

  # Опыт работы
  # experiences = ['between1And3']
  experience = ''
  if experiences:
    experience = ''.join(f'&experience={exper}' for exper in experiences)

  # Специализации
  # prof_roles = [96, 40, 156]
  professional_role = ''
  if prof_roles:
    professional_role = ''.join(f'&professional_role={prof_role}'
                                for prof_role in prof_roles)

  # Пол
  # gen = "male"
  # gen = "female"
  # gender_if = True
  gender = f'&gender={gen}'
  label_gender = ''
  if gender_if: label_gender = f'&label=only_with_gender'

  # Уровень дохода
  # salary_min = 500
  # salary_max = 1000
  # currency = 'EUR'
  # currency = 'USD'
  # salary_if = True
  salary_from = ''
  salary_to = ''
  label_salary = ''
  currency_code = ''
  if currency in ['EUR', 'USD']: currency_code = f'&currency_code={currency}'
  if salary_min: salary_from = f'&salary_from={salary_min}'
  if salary_max: salary_to = f'&salary_to={salary_max}'
  if salary_if: label_salary = f'&label=only_with_salary'

  # Гражданство, страна
  # countries = [113, 16]
  citizenship = ''
  if countries:
    citizenship = ''.join(f'&citizenship={country}' for country in countries)

  # Есть фото, есть  автомобиль
  # foto_if = True
  # vehicle_if = True
  label_foto = ''
  label_vehicle = ''
  if foto_if: label_foto = f'&label=only_with_photo'
  if vehicle_if: label_vehicle = f'&label=only_with_vehicle'

  # Образование
  # educations = ['higher', 'candidate']
  education_level = ''
  if educations:
    education_level = ''.join(f'&education_level={education}'
                              for education in educations)

  # Учебное заведение
  # universities = [39872, 39650]
  university = ''
  if universities:
    university = ''.join(f'&university={univer}' for univer in universities)

  # Подтвержденные навыки
  # ver_skills = [1114, 845, 2350]
  verified_skills = ''
  if ver_skills:
    verified_skills = ''.join(f'&verified_skills={verif_skill}'
                              for verif_skill in ver_skills)

  # Ключевые навыки
  # key_skills = [3093, 6958, 14886, 1114]
  skill = ''
  if key_skills:
    skill = ''.join(f'&skill={key_skill}' for key_skill in key_skills)

  # Разрешение на работу, страна
  # work_countries = [16, 213]
  work_ticket = ''
  if work_countries:
    work_ticket = ''.join(f'&work_ticket={work_country}'
                          for work_country in work_countries)

  # Категория прав
  # driver_types = ['B', 'C']
  driver_license_types = ''
  if driver_types:
    driver_license_types = ''.join(f'&driver_license_types={type_drive}'
                                   for type_drive in driver_types)

  # Знание языков, уровень
  # Дополнительно по английскому языку можно указать подтвержденные знания
  # languages = ['rus.l1', 'bel.c2', 'eng.c1', 'zho.b1']
  # verif_languages = '57.5'
  language = ''
  if languages:
    language = ''.join(f'&language={lang}' for lang in languages)
  verified_languages = ''
  if languages:
    verified_languages = f'&verified_languages={verif_languages}'

  # Создаем ссылку для поиска резюме по заданным параметрам
  base_url=\
  f"https://hh.ru/search/resume?text={text}{area}&isDefaultArea=true\
&exp_period=all_time{logic}{pos}{order_by}{search_period}{items_on_page}{relocation}\
{filter_exp_industry}{filter_exp_period}{job_search_status}{age_from}{age_to}\
{label_age}{employment}{schedule}{experience}{professional_role}{gender}\
{label_gender}{currency_code}{salary_from}{salary_to}{label_salary}\
{citizenship}{label_foto}{label_vehicle}{education_level}{university}\
{verified_skills}{skill}{work_ticket}{driver_license_types}{language}\
{verified_languages}"

  return base_url

# %% [markdown]
# ### Функция парсинга ссылок резюме

# %%
  # Создаем объект для передачи заголовка
  # Создадим юзер-агента, общего для всех запросов
  ua = fake_useragent.UserAgent()

# %%
# Функция для получения ссылок по запросу
def get_links(base_url):

  data = requests.get(
      url=base_url,
      headers = {"user-agent":ua.random})

  # Если произошла ошибка, выходим из функции
  if data.status_code != 200:
    print(f"Ошибка запроса: HTTP {data.status_code}")
    return

  # В переменную soup передаем содержание полученной страницы
  soup = BeautifulSoup(data.content, "lxml")
  # Найдем количество страниц
  # Внизу открытой страницы hh находим количество страниц 250; нажимаем правой кнопкой мыши и далее "Проверить"
  # В открывшемся справа окне, вверху нажимаем кнопку проверить и выбираем количество страниц (250)
  # Находим div class = "pager", и вводим его в attrs
  # Далее надо найти все "span" и взять последний, т.к. там указано 250
  # Далее у последнего span надо получить ссылку "a"
  # В ссылке надо взять "span", и в "span" взять текст
  # Полученное значение переводим в int
  try:
    page_count = int(soup.find("div", attrs={"class":"pager"}).find_all("span",recursive=False)[-1].find("a").find("span").text)
  except Exception as e:
    print("Ошибка при получении количества страниц: ", e)
    return

  print (f'Всего найдено страниц: {page_count}')

  for page in range(page_count):
    try:
      # Создаем заголовок и передаем туда случайный заголовок из созданного объекта
      # В запрос передаем страницу
      data = requests.get(
        url=f"{base_url}&page={page}",
        headers = {"user-agent":ua.random}
      )

      if data.status_code != 200:
        print(f"Пропуск страницы {page} из-за ошибки HTTP {data.status_code}")
        continue
      soup = BeautifulSoup(data.content, "lxml")
      # Выбираем на hh любое резюме, нам нужна ссылка "a", у нее нужен атрибут "data-qa"; этот атрибут вставляем в soup
      # Проходим по всем ссылкам
      for a in soup.find_all("a", attrs={"data-qa":"serp-item__title"}):
        # в каждой ссылке "a" нам нужен адрес сайта в "attrs"
        # в адресе сайта нужно всё до знака "?", поэтому разбиваем ссылку по знаку "?" и берем первый элемент
        yield f"https://hh.ru{a.attrs['href'].split('?')[0]}"

      print (f'Обработана страница: {page}')
    except Exception as e:
      print(f"Ошибка при обработке страницы {page}: {e}")
    time.sleep(1)

# %% [markdown]
# ### Функция парсинга информации из каждого резюме

# %%
# Функция для получения данных резюме
def get_resume(link_resume):

  # Делаем запрос к переданной ссылке
  data = requests.get(
      url = link_resume,
      headers={"user-agent":ua.random}
  )
  if data.status_code != 200:
    return

  soup = BeautifulSoup(data.content, "lxml")

  # Для обеспечения стабильной работы сразу инициализируем переменные
  id_link = "",
  gender = "",
  age = "",
  date_of_birth = "",
  about_me = "",
  education = "",
  language = "",
  job_search_status = "",
  place_of_residence = "",
  moving = "",
  business_trip = "",
  name = "",
  salary = "",
  specialization_schedule = "",
  experience_all_period = "",
  experience = "",
  tags = ""
  link = ""

  # Вытащим из ссылки id резюме
  id_link = link_resume.split("/")[-1]

  # Спарсим пол (мужчина / женщина)
  try:
    gender = soup.find("span", attrs={"data-qa": "resume-personal-gender"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    gender = ""

  # Спарсим возраст
  try:
    age = soup.find("span", attrs={"data-qa": "resume-personal-age"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    age = ""

  # Спарсим дату рождения
  try:
    date_of_birth = soup.find("span", attrs={"data-qa":"resume-personal-birthday"}).text.replace("\xa0", " ")
  except:
    date_of_birth = ""

  # Спарсим статус поиска работы (Активно ищет работу / Не ищет работу / Рассматривает предложения / и т.д.)
  try:
    job_search_status = soup.find("span", attrs={"data-qa": "job-search-status"}).text
  except:
    job_search_status = ""

  # Спарсим информацию "О себе"
  try:
    about_me = soup.find("div", attrs={"data-qa": "resume-block-skills-content"}).text.strip()
  except:
    about_me = ""

  # Спарсим информацию об образовании
  try:
    # Находим блок образования и извлекаем из него текст
    education_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-education"})
    education = []
    for block in education_blocks:
      education_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
      education.append(education_info)
  except:
    education = []

  # Спарсим информацию о знании языков
  try:
    language_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-languages"})
    language = []
    for block in language_blocks:
      lang_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
      language.append(lang_info)
  except:
    language = []


  # Спарсим место проживания (город, метро)
  # Создадим пустой список, куда будем добавлять "Город", "Метро"
  list_of_residence = []
  # Парсим "Город" и при удачном парсинге добавляем его в пустой список
  city = soup.find("span", attrs={"data-qa":"resume-personal-address"})
  if city: list_of_residence.append(city.text.replace("\xa0", " "))
  # Парсим "Метро" и при удачном парсинге добавляем его в пустой список
  # Не во всех резюме есть "Метро", поэтому делаем проверку удачного парсинга
  metro = soup.find("span", attrs={"data-qa":"resume-personal-metro"})
  if metro: list_of_residence.append(metro.text.replace("\xa0", " "))
  # Соединяем город и метро, и получаем место проживания
  place_of_residence = ', '.join(part_residence for part_residence in list_of_residence).strip()

  # Спарсим готовность к переезду, командировкам
  try:
    # Находим весь текст в блоке "Готовность к переезду/командировкам"
    movings = soup.find(attrs={"class":"bloko-translate-guard"}).text.replace("\xa0", " ")
    # Разделяем текст на части по запятой
    parts = movings.split(',')
    # Создадим пустой список, куда будем добавлять фразы касательно переезда
    moving_list = []
    # Проходимся по частям текста за исключением последней,
    # т.к. последняя часть - это готовность к командировкам
    for part in parts[:-1]:
      # Если часть текста не содержится в "Место проживания"
      # добавляем ее в пустой список
      if part not in place_of_residence:
        moving_list.append(part)
    # Полученный список соединяем и получаем "Готовность к переезду"
    moving = ','.join(part_moving for part_moving in moving_list).strip()
    # Берем последнюю часть, получаем готовность к командировкам
    business_trip = parts[-1].strip()
  except:
    moving = ""
    business_trip = ""

  # Спарсим название позиции
  try:
    name = soup.find(attrs={"class":"resume-block__title-text"}).text
  except:
    name = ""

  # Спарсим зарплату и уберем лишние символы (\u2009, \xa0)
  try:
    salary = soup.find(attrs={"class":"resume-block__salary"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    salary = ""

  # Спарсим специализации и график работы
  try:
    # Находим все блоки с class "resume-block-container"
    specialized_blocks = soup.find_all(attrs={"class":"resume-block-container"})
    # Проверим каждый блок и найдем блок в котором есть class "resume-block__specialization"
    for block in specialized_blocks:
      if block.find(attrs={"class":"resume-block__specialization"}):
        # Запишем в переменную текст найденного блока
        # Предварительно добавив пробелы перед заглавными буквами и затем удалив лишние пробелы (в начале)
        specialization_schedule = re.sub(r'([А-ЯA-Z])', r' \1', block.text).strip()
  except:
    specialization_schedule = ""

  # Спарсим общее время опыта работы
  try:
    experience_all_period = soup.find(attrs={"class":"resume-block__title-text resume-block__title-text_sub"}).text.replace("\xa0", " ")
  except:
    experience_all_period = ""

  # Спарсим опыт работы
  try:
    # Найдем все блоки с class="resume-block-item-gap" в блоке с "data-qa":"resume-block-experience"
    # В самом первом блоке информация дублируется, поэтому список создадим без самого первого элемента
    blocks_item_gap = soup.find(attrs={"data-qa":"resume-block-experience"}).find_all(attrs={"class":"resume-block-item-gap"})[1:]
    # Создадим паттерн для последующего поиска блоков
    reexp = re.compile('bloko-column.*')
    blocks_all = [] # Сюда будем складывать найденные блоки
    experience = [] # Сюда будем складывать итоговый текст
    # Проходимся по каждому вышенайденному блоку и находим все блоки с атрибутом class по заданному паттерну
    for block_item in blocks_item_gap:
      blocks_all.append (block_item.find_all(class_=reexp)[1:]) # Аналогично нам нужен список без самого первого элемента
    # Проходимся по каждому списку блоков в общем списке blocks_all
    for block in blocks_all:
      # Проходимся по каждому элементу
      for data in block:
        # print(data.text.replace("\xa0", " "))
        # Полученный текст из каждого элемента складываем в итоговый список
        experience.append(data.text.replace("\xa0", " "))
  except:
    experience = ""

  # Спарсим ключевые навыки
  # Находим атрибут, где находятся все ключевые навыки (data-qa = "skills-table); далее находим class для каждого отдельного навыка, оставляем class с text
  try:
    tags = [tag.text for tag in soup.find(attrs={"data-qa":"skills-table"}).find_all(attrs={"class":"bloko-tag__section_text"})]
  except:
    tags = []


  # Собираем все найденные атрибуты в словарь, в конце словаря добавляем url-адрес резюме
  resume = {
      "id":id_link,
      "gender":gender,
      "age":age,
      "date_of_birth":date_of_birth,
      "about_me": about_me,
      "education": education,
      "language": language,
      "job_search_status":job_search_status,
      "place_of_residence":place_of_residence,
      "moving":moving,
      "business_trip":business_trip,
      "name":name,
      "salary":salary,
      "specialization_schedule":specialization_schedule,
      "experience_all_period":experience_all_period,
      "experience":experience,
      "tags":tags,
      "link":link_resume
  }
  return resume

# %% [markdown]
# ### Функция парсинга и запись результата в csv файл

# %%
# Функция парсинга резюме по ссылкам и записи результатов в файл
search = ""
def result_resumes(link_resume: list,
                   file_path = f'/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv',
                   fieldnames = ['id', 'gender', 'age', 'date_of_birth', 'about_me',
                    'education', 'language', 'job_search_status',
                    'place_of_residence', 'moving', 'business_trip', 'name',
                    'salary', 'specialization_schedule',
                    'experience_all_period', 'experience', 'tags', 'link']):
  '''
  :link_resume: список ссылок резюме
  :file_path: путь к файлу для сохранения результатов парсинга
  :fieldnames: названия столбцов в файле
  '''

  # Проверяем наличие файла
  if not os.path.isfile(file_path):
    # Если файла не существует, создаем новый файл
    with open(file_path, 'w', newline='', encoding='utf-8') as res_file:
      writer = csv.DictWriter(res_file, fieldnames=fieldnames)
      # Записываем заголовки столбцов
      writer.writeheader()

  # Для отображения прогресса разделим количество ссылок на группы по 20 штук
  groups = [link_resume[i:i+20] for i in range(0, len(link_resume), 20)]


  # Функция для создания синего прогресс-бара
  def blue_bar(iterable, **kwargs):
      # Создаем прогресс-бар tqdm
      bar = tqdm(iterable, **kwargs)
      # Устанавливаем цвет текста и прогресс-бара в синий
      bar.bar_format = "\033[34m{l_bar}{bar}{r_bar}\033[0m"
      return bar

  # открываем файл в режиме добавления (a - append)
  with open(file_path, 'a', newline='', encoding='utf-8') as res_file:
    writer = csv.DictWriter(res_file, fieldnames=fieldnames)
    # Прогресс-бар для каждой группы ссылок
    for idx, group in enumerate(groups[:-1], start=1):
      # Используем tqdm для отслеживания прогресса обработки
      for link in blue_bar(group, desc=f'Обработка {idx} группы резюме', unit='резюме'):
        resume_data = get_resume(link)
        if resume_data: # При успешном парсинге резюме
          # # открываем файл в режиме добавления (a - append)
          # with open(file_path, 'a', newline='', encoding='utf-8') as res_file:
            # writer = csv.DictWriter(res_file, fieldnames=fieldnames)
          writer.writerow(resume_data)  # Записываем данные в CSV
          # print (resume_data)
        time.sleep(1)
      print(f"Группа {idx} обработана!")

    # Отдельно обрабатываем последнюю группу
    last_idx = len(groups)
    for link in blue_bar(groups[-1], desc=f'Обработка {last_idx} группы резюме', unit='резюме'):
        resume_data = get_resume(link)
        if resume_data: # При успешном парсинге резюме
          # # открываем файл в режиме добавления (a - append)
          # with open(file_path, 'a', newline='', encoding='utf-8') as res_file:
          #   writer = csv.DictWriter(res_file, fieldnames=fieldnames)
          writer.writerow(resume_data)  # Записываем данные в CSV
        time.sleep(1)
    print(f"Последняя группа ({last_idx}) обработана!")

# %% [markdown]
# ### Результирующая функция. <br><br>На входе ключевое слово/фраза для поиска и путь к файлам, <br> на выходе два файла csv: <br>1. перечень ссылок резюме; 2. результат парсинга резюме

# %% [markdown]
# ### Запуск результирующей функции

# %%
import csv
import time

def result_resumes(link_resume, file_path):
    # Открываем файл в режиме добавления 'a' для записи данных без их потери
    with open(file_path, 'a', newline='', encoding='utf-8') as res_file:
        # Названия столбцов
        fieldnames = ['id', 'gender', 'age', 'date_of_birth', 'about_me',
                      'education', 'language', 'job_search_status',
                      'place_of_residence', 'moving', 'business_trip', 'name',
                      'salary', 'specialization_schedule',
                      'experience_all_period', 'experience', 'tags', 'link']
        writer = csv.DictWriter(res_file, fieldnames=fieldnames)
        # Проверяем, нужно ли писать заголовок (только если файл был только что создан)
        if res_file.tell() == 0:
            writer.writeheader()

        # Итерация по списку ссылок и запись результатов
        for link in link_resume:
            resume_data = get_resume(link)
            if resume_data:
                writer.writerow(resume_data)
            print(resume_data)  # Для отладки
            time.sleep(1)  # Задержка для снижения нагрузки на сервер

def links_and_resumes(search):
    link_path = f"/content/drive/MyDrive/Practice2/parsinghh/link_resume_{search}.csv"
    resume_path = f"/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv"

    # Получаем ссылку-запрос для последующего парсинга ссылок резюме
    base_url = ref_search_resume(search)
    link_resume = [a for a in get_links(base_url)]

    # Записываем полученные ссылки в csv-файл
    with open(link_path, 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        for resume in link_resume:
            writer.writerow([resume])

    # Парсим резюме и записываем в файл
    result_resumes(link_resume, file_path=resume_path)

# Запуск функции с поисковым запросом
links_and_resumes("Unity")
# Out:
# Всего найдено страниц: 27
# Обработана страница: 0
# Обработана страница: 1
# Обработана страница: 2
# Обработана страница: 3
# Обработана страница: 4
# Обработана страница: 5
# Обработана страница: 6
# Обработана страница: 7
# Обработана страница: 8
# Обработана страница: 9
# Обработана страница: 10
# Обработана страница: 11
# Обработана страница: 12
# Обработана страница: 13
# Обработана страница: 14
# Обработана страница: 15
# Обработана страница: 16
# Обработана страница: 17
# Обработана страница: 18
# Обработана страница: 19
# Обработана страница: 20
# Обработана страница: 21
# Обработана страница: 22
# Обработана страница: 23
# Обработана страница: 24
# Обработана страница: 25
# Обработана страница: 26
# {'id': '2900b8ec00081609e20039ed1f47435554724b', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '24 июля 2002', 'about_me': 'github профиль: https://github.com/contr4s.', 'education': ['Неоконченное высшее образование2025НИУ ИТМО, Санкт-ПетербургИнформационных технологий и программирования, Информационные системы и технологии (инженер)'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Санкт-Петербург, м. Комендантский проспект', 'moving': 'не готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Unity developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года', 'experience': ['Июль 2022 — Декабрь 20231 год 6 месяцев', 'A17 gamesa17.games/Unity разработчикЗанимался разработкой с нуля мобильного шутера от третьего лица с элементами roguelike и arena survival в небольшой инди команде. \n\nОсновные задачи:\n- Разработка новой игровой логики по тз от геймдизайнеров\n- Разработка поведения (ai) ботов\n- Написание кода для взаимодействия с сервером\n- Подключение ui и ux\n- Парсинг конфигов с google sheets\n- Подключение различных sdk (аутентификация, аналитика, уведомления)\n\nПроект был построен на архитектуре mvvm. Каждая система представляла собой отдельный asmdef. Для взаимодействия с сервером использовался grpc и обработка запросов с помощью UniTask. В качестве di фреймворка использовался Zenject, для анимаций DoTween. Также были настроены addresables для доставки контента. Для сборки билдов был настроен ci/cd на Jenkins.\n\nПроект в сторе: https://play.google.com/store/apps/details?id=com.A17Games.NewOrion&hl=en\n\nЗа рекомендацией можно обращаться к "Куневич Станислав CEO A17Games, тел.: +7 910 403 6735, email: gabage@list.ru"', 'Июнь 2021 — Июнь 20221 год 1 месяц', 'ClickLogclicklog.io/Unity DeveloperРаботал над клиентской частью 3D WebGL приложения, которое показывала как наиболее оптимально расположить грузы внутри грузовика. Занимался UI и UX, а также обработкой различных данных (парсинг джейсонов и возвращение их клиентам в красивом виде). Приходилось иметь дело с большим количеством легаси кода.', 'Январь 2021 — Декабрь 20211 год', 'Game Wheels StudioUnity developerРаботал над мобильным проектом в жанре tower defense.\nЗанимался всеми техническими аспектами игры: разрабатывал архитектуру, программировал игровую логику, рефакторил код, верстал интерфейс, работал над конфигами, занимался оптимизацией и разрабатывал расширения для редактора.'], 'tags': ['Unity', 'C#', 'MS Visual Studio', 'C/C++', ' Git', '.Net'], 'link': 'https://hh.ru/resume/2900b8ec00081609e20039ed1f47435554724b'}
# {'id': '36b1888c00071042f40039ed1f7255546f6474', 'gender': 'Мужчина', 'age': '40 лет', 'date_of_birth': '11 августа 1983', 'about_me': 'Проект на гитхабе, в котором сделал акцент на архитектуру\nhttps://github.com/DeMoZ/U3d_CCG\nhttps://github.com/DeMoZ/U3d_Flips\n\nВизуально о моих проектах https://roman-kolychev.my.canva.site/\n\nВ свободное и рабочее время программирую в Unity3d(C#)\nНе курю и не употребляю алкоголь. Занимаюсь спортом.', 'education': ['Высшее образование2006Sakhalin State Academy of Economic and ManagmentFaculty of Economics, Applied Informatics2003Sakhalin State College of Business and Computer ScienceComputer Science, Programmer'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Москва', 'moving': 'хочу переехать', 'business_trip': 'готов к командировкам', 'name': 'Unity developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 4 года 7 месяцев', 'experience': ['Ноябрь 2023 — Апрель 20246 месяцев', 'Red RiftСША, www.linkedin.com/company/redrift/Информационные технологии, системная интеграция, интернет... Показать ещеUnity DeveloperПоддержка и развитие сборника новелл (Spart - interactive story)\nhttps://apps.apple.com/us/app/storyspark-interactive-story/id1665916639\nhttps://play.google.com/store/apps/details?id=com.RedRift.StorySpark\n\n• Собирал AssetBundle для нового контента.\n• Внедрил использование Addressables для более удобного управления контентом.\n• Использовал Unity Cloud для создания сборок на различные платформы.\n• Обновлял дизайн игровых элементов: переработка окон игры с новым дизайном и дополненной логикой.\n• Внедрял новые функции (достижения и обучающий режим)\n• Исправил большое количество багов\n', 'Август 2022 — Ноябрь 20231 год 4 месяца', 'NADSATwww.linkedin.com/company/nadsatUnity DeveloperРабота над новеллой в  команде из 15 человек. \nНаписание базы кода проекта с нуля. Разработка архитектуры и выбор используемых подходов в разработке.\nВ проекте используется MVx подобная архитектура без бизнес логиги на МоноБехах, Wwise audio system, UniRX, DOTween, Unity Animations, Async/Task, Odin, VisualElemnts, I2Localize, Google SpeechToText(для субтитров)\n\nВизуально о проектах  https://roman-kolychev.my.canva.site/\nMVP проект как пример кода https://github.com/DeMoZ/Midline85\nhttps://store.steampowered.com/app/2384710/Midline_85/', 'Декабрь 2021 — Сентябрь 202210 месяцев', 'Nakusi DevМосква, nakusi.games/Информационные технологии, системная интеграция, интернет... Показать ещеUnity DeveloperРазработка клиент серверной игры жанра match3 (2).\nhttps://play.google.com/store/apps/details?id=makeover.puzzle.match.blast.fashion.home.design.decorate\n\nДостижения:\n1. Проект Happy Happens! доведен до стадии TechLaunch.\n2. Написал логику взаимодействия с Facebook. Загрузка друзей.\n3. Написал систему привязки игрового профиля к Facebook, GooglePlay, Appstore Connect.\n4. Реализовано сетевое взаимодействие игрового профиля с сервером с помощью HttpClient.\n5. Реализована система игровой почты.\n6. Реализованы читы для команды QA.\n7. Реализована ежедневная награда и другие сплывающие окна (верстка и логика).', 'Июль 2021 — Декабрь 20216 месяцев', 'Мобильные ТелеСистемы (МТС)Москва, www.mts.ruИнформационные технологии, системная интеграция, интернет... Показать ещеUnity3d разработчикРазработка клиент серверной игры жанра city builder.\nhttps://play.google.com/store/apps/details?id=ru.mts.clientworld&hl=ru&gl=US\n\nДостижения\n1. Проект МТС Cashback City выведен на стадию Soft Launch.\n2. Рефакторинг устаревшего кода.\n3. Реализован макет и логика пользовательского интерфейса для всплывающих окон в игре, которые производят игровые ресурсы и элементы игрового города.', 'Декабрь 2020 — Июль 20218 месяцев', 'Системы управленияМосква, c ...
# {'id': 'fe10fee40008c1782d0039ed1f567659573275', 'gender': 'Мужчина', 'age': '24 года', 'date_of_birth': '21 июля 1999', 'about_me': 'Полное резюме - https://drive.google.com/file/d/1UcbjBp5OHOGo7IzvzYCus5KxG75FdmW7/view?usp=drive_link', 'education': ['ОбразованиеСреднее образование'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Казань', 'moving': 'готов к переезду', 'business_trip': 'готов к редким командировкам', 'name': 'Unity Developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, проектная работа График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 11 месяцев', 'experience': ['Июль 2021 — по настоящее время2 года 11 месяцев', 'Eudokia GamesUnity-разработчикРазработка новых механик, строение архитектуры приложения, верстка UI под пк/мобильные устройства, оптимизация приложения(пк, андроид), установка SDK(аналитика, реклама), работа с анимациями, работа с Behaviour Tree, разработка инструментариев для дизайнеров и т.д'], 'tags': ['Хорошее знание движка Unity', 'Знание принципов ООП', 'Применение паттернов проектирования', 'Опыт разработки в команде', 'C#', 'Git', 'Python', 'Английский язык', 'Entitas', 'Unity', 'Android'], 'link': 'https://hh.ru/resume/fe10fee40008c1782d0039ed1f567659573275'}
# {'id': '1dbf5ab60008b27b690039ed1f504c7a486359', 'gender': 'Мужчина', 'age': '22 года', 'date_of_birth': '10 октября 2001', 'about_me': 'О себе: Быстрообучаем + часто использую ChatGPT в своей работе, энтузиаст, спокоен, сконцентрированный, желающий учиться и продвигаться в своей специальности, ответственный,\nОбожаю игровую индустрию как в плане разработки, так и в плане самих игр.\nПример некоторых работ :https://www.youtube.com/@user-cd9pj8hq8k/videos\n\nСкиллы:\n-Опыт разработки сетевых игры, используя готовые решение(Mirror, Photon)\nВот пример работы в составе команды над игрой написанной на Mirror :\nWebGl Game Multiplayer https://serejadeveloper.itch.io/2332sddsadsa\nВот на нее обзор https://www.youtube.com/watch?v=4bW7_a9XcsI\n\n-Опыт и навыки оптимизации игры через Profiler unity, и через готовые решение по типу Occlusion, mesh combibe и других ассетов а также внутренних Unity функций\n-Опыт работы с внутренним Аниматором Unity а также другими решениями по типу DOTWEEN под UI и Объектов \n-Опыт подключение Различных sdk  по типу рекламы и т д.\n-Хорошие навыки использование ассетов и понимание где писать собственные решения\n-Опыт работы с Шейдерами и написание простых в ShaderGraph\n-Опыт работы с VFX\n-Знание графических Render Pipeline(URP, HDRP, Built in)\n-Знание и понимание и применение ООП и а также следованию SOLID и многих других паттернов \n проектирования (State Machine, Decorator, Observer, Factory, Object Pool, Singleton, Visitor).\n-Знаком с MVVM\n-Знаком с Unity DOTS, ECS, Zenject, Job System\n-Технический английский, использую англоязычный сегмент', 'education': ['ОбразованиеСреднее специальное образование'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Москва', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Unity developer', 'salary': '70000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 3 месяца', 'experience': ['Август 2023 — Январь 20246 месяцев', 'Digen-ITМоскваUnity developerРазработка программного обеспечения «Виртуальный тренажерный комплекс (VR-тренажер) ', 'Июль 2023 — Август 20232 месяца', 'HyperGamesUnity developerРазработка мобильных игр, стек: APPLOVIN, Facebook, GameAnalytics(GA),Tenjin, In app Purchasing, ADS\nРезультат https://play.google.com/store/apps/details?id=com.games.stickman.match', 'Июнь 2022 — Май 20231 год', 'ND CREATORSUnity Developer\nОбязанности:\n- Разработка hyper casual игр с нуля до релиза\n- Профайлинг и оптимизация\n- Интеграция SDK\n\nСтек:\n- C#, Unity, ООП, Паттерны проектирования, SOLID\n- Zenject,  IK, Ragdoll, Physics, Animations, GrassCute\n- Cinemachine, DOTween, Obi rope, Obi Fluid, Realistic Car Controller, Universal Vehicle Controller Without dependencies\n- Github\nРезультат работ \nhttps://play.google.com/store/apps/details?id=com.ndcreators.golfclubidle\nhttps://play.google.com/store/apps/details?id=com.ndcreators.ninjamaster\nhttps://play.google.com/store/apps/details?id=com.ndcreators.drivetosurvive\nhttps://play.google.com/store/apps/details?id=com.ndcreators.helicoptersupport\nhttps://play.google.com/store/apps/details?id=com.ndcreators.tankmerger\nhttps://play.google.com/store/apps/details?id=com.ndcreators.mysummerparty&hl=en_US&gl=US\nhttps://play.google.com/store/apps/details?id=com.ndcreators.crowdtarget\nhttps://play.google.com/store/apps/details?id=com.ndcreators.richisland\nhttps://play.google.com/store/apps/details?id=com.ndcreators.shreddingmachine', 'Апрель 2022 — Июнь 20223 месяца', 'ДомичиМосква, www.domichi.ruУправление многопрофильными активами... Показать ещеUnity developerОбязанности:\n- разработка идеи для приложения на спорт тематику\n- Верстка и разработка логики для UI\n- Профайлинг ...
# {'id': '9f8d59630007321eac0039ed1f6f674b34506d', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '27 ноября 2002', 'about_me': 'Профессиональный опыт:\nПроектирование и разработка игровых систем с использованием принципов ECS (Entity-Component-System).\nПрименение принципов объектно-ориентированного программирования (OOP) для создания чистого и масштабируемого кода.\nИспользование фреймворка Zenject для управления зависимостями и внедрения зависимостей.\nРеализация асинхронных и реактивных систем с использованием UniRx и UniTask.\nПрактика SOLID, DRY, KISS, YAGNI принципов в процессе разработки.\nУчастие в полном цикле разработки: от концепции и проектирования до релиза и поддержки.\n\nНавыки:\nЯзыки программирования: C#\nИнструменты и технологии: Unity, Visual Studio, Git.\nПринципы программирования: ECS (Entity-Component-System), OOP (Object-Oriented Programming), KISS (Keep It Simple, Stupid), SOLID, DRY, YAGNI.\nФреймворки и библиотеки: ECS by Leo, Zenject, UniRx, UniTask.\n\nДополнительная информация:\nУчастие в сообществах Unity и активное общение с разработчиками.\nПостоянное обучение новым технологиям и инструментам.\nДоступность для новых проектов и готовность к дополнительным задачам.', 'education': ['Среднее специальное образование2022ГБПОУ ГКПрограммирование в компьютерных системах'], 'language': ['Знание языковРусский — РоднойАнглийский — A2 — Элементарный'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Пятигорск', 'moving': 'не готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Unity Developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 4 года 4 месяца', 'experience': ['Февраль 2020 — по настоящее время4 года 4 месяца', 'ФрилансUnity DeveloperЗанимался созданием с нуля проектов и внедрял, изменял в готовых проектах. Работал над проектами от гиперказуала до мидкор, как в составе группы с другими сотрудниками, так и один.'], 'tags': ['Unity', 'C#', 'Git', 'ООП', 'LINQ', 'SOLID', 'Entity Framework', 'Алгоритмизация', 'Фреймворки', 'Умение работать в команде', 'Математика', 'Модульное тестирование'], 'link': 'https://hh.ru/resume/9f8d59630007321eac0039ed1f6f674b34506d'}
# {'id': 'cd4e93150008c179d40039ed1f705241544442', 'gender': 'Мужчина', 'age': '26 лет', 'date_of_birth': '12 ноября 1997', 'about_me': 'Знакомство c Unity Осенью 2019 года начал изучать программирование и Unity . Параллельно участвовал в проектах на энтузиазме. Чуть менее чем через год с командой знакомых создал свой первый Unity проект и вышли с ним на Patreon\n\nИмею опыт разработки проектов под мобильные устройства.\nИмею опыт разработки мультиплеерных проектов.', 'education': ['Среднее специальное образование2021Санкт-Петербургский политехнический университет Петра Великого, Санкт-ПетербургСПО, Техник-Программист'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Санкт-Петербург, м. Комендантский проспект', 'moving': 'не готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Программист Unity', 'salary': '90000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день', 'experience_all_period': 'Опыт работы 4 года 5 месяцев', 'experience': ['Март 2023 — по настоящее время1 год 3 месяца', 'It kidsПреподовательПреподаю группу по unity', 'Октябрь 2021 — по настоящее время2 года 8 месяцев', 'North labСанкт-Петербург, northlabgames.ru/unity developerРазработка архитектуры проекта и ее реализация.\nРеализация прототипов а также полный цикл разработки \nВнедрение Sdk \nВерстка UI', 'Январь 2020 — Декабрь 20223 года', 'Digital BananaПреподавательПреподавал unity у группы подростков а также занимался индивидуально', 'Май 2020 — Сентябрь 20211 год 5 месяцев', 'Magic FingersUnity DeveloperРазработка архитектуры и ее реализация (работа лежала полностью на мне так я был единственным разработчиком)\nРабота с анимацией и UI', 'Декабрь 2020 — Январь 20212 месяца', 'Nimco_gamesJunior Unreal Engine Developer- Blueprint скриптинг под Ureal Engine 4.25+ ', 'Август 2020 — Декабрь 20205 месяцев', 'Black Caviar GamesJunior Unity DeveloperРазработка архитектуры проекта и ее реализация.\nСогласование архитектуры с ведущим разработчиком.\nПодключение бекэнда (Playfab).\n\n'], 'tags': ['Работоспособность', 'Unity', 'Git', 'C#', '.NET Framework', 'ООП', 'Atlassian Jira', 'MS Visual Studio', 'Работа в команде', 'Английский язык', 'Unreal Engine 4', 'Blueprints', 'slack', 'NoSQL', 'Firebase', 'MVC', 'ASP.NET', 'DRY', 'KISS', 'Redis', 'Visual Studio C#', 'ASP.NET Core'], 'link': 'https://hh.ru/resume/cd4e93150008c179d40039ed1f705241544442'}
# {'id': 'ec377a1900076901ca0039ed1f48654651326d', 'gender': 'Мужчина', 'age': '23 года', 'date_of_birth': '28 ноября 2000', 'about_me': 'Git : https://github.com/KvaiTorGrad\nYandex Game: https://yandex.ru/games/developer/82040\nЯ прошел полный цикл разработки от идеи до выпуска игры. Логика игрового процесса, работа с пользовательским интерфейсом, прототипирование, работа с активами, сборками, балансом, интеграция SDK. Я знаю и активно использую шаблоны проектирования.\nТак же есть опыт в публикациях игр на Google Play', 'education': ['Среднее специальное образование2020БТЭиРАвтоматизация технологических процессов и производств (по отраслям)'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Брянск', 'moving': 'готов к переезду', 'business_trip': 'готов к редким командировкам', 'name': 'Unity developer', 'salary': '60000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 5 месяцев', 'experience': ['Сентябрь 2023 — по настоящее время9 месяцев', 'SkillfactoryМосква, skillfactory.ru/Ментор по курсу UnityПомощь студентам в изучении движка Unity и программы Blender', 'Январь 2022 — по настоящее время2 года 5 месяцев', 'Skysmartskysmart.ru/Образовательные учреждения... Показать ещеПреподаватель по разработке игр на движке UnityОбучаю учеников от 7-18 лет базовым знаниям программирования игр на Unity.', 'Март 2023 — Декабрь 202310 месяцев', 'VrTronБрянскИнформационные технологии, системная интеграция, интернет... Показать ещеUnity developer- Создание прототипов\n- Настройка сетевого подключения\n- Работа с инверсной кинематикой\n- Настройка контроллеров и UI под Vr аппаратуру\n- Создание приложений с нуля\n- Работа с UI\n- Рефакторинг;\n- Разработка архитектуры проекта;\n- Интеграция SDK;\n- Разработка новых функций;\n- Исправление ошибок.\n\nТехнологии:\n-Plastic SCM\n- NavMesh\n- System Input\n- Oculus \n- Networking\n- Ragdoll\n- URP\n- Post Processing\n- Inverse Kinematics'], 'tags': ['C#', 'Visual Studio C#', 'Git', 'Работа в команде', 'Networking', 'SOLID', 'ООП', 'VR', 'Умение разбираться в чужом коде', 'Программирование', 'Паттерны проектирования', 'Game Programming', 'Addressable', 'Android', 'PC', 'Unity'], 'link': 'https://hh.ru/resume/ec377a1900076901ca0039ed1f48654651326d'}
# {'id': '060502b40006e58ecf0039ed1f41776c374e68', 'gender': 'Мужчина', 'age': '34 года', 'date_of_birth': '17 января 1990', 'about_me': 'Unity Разработчик. Интересно работать над новыми проектами. Люблю создавать новые сложные механики. Unity считаю делом всей своей жизни. Заинтересован созданием ролевых игр на движке Unity.', 'education': ['Высшее образование2015Петрозаводский государственный университет, Петрозаводскфизико-технический, Автоматизированные системы обработки информации и управления'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Краснодар', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Программист Unity 3D', 'salary': '70000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 9 лет 2 месяца', 'experience': ['Апрель 2015 — по настоящее время9 лет 2 месяца', 'AlexanderDevalexanderdev.ruПрограммист-разработчикВеду свой сайт-блог разработчика http://alexanderdev.ru/ с 2015года, а также YouTube-канал по разработке мморпг на юнити.\nВ настоящий момент разрабатываю тактическую ролевую игру с пошаговыми сражениями на сетке, на движке Unity. Ранее снимал обучающие видео по разработке для CMS WordPress.\nТакже ранее снимал на youtube канал "дневник разработчика" - по этапам разработки ролевой игры(ММОРПГ). Проект был переосмыслен и жанр изменён с ММОРПГ на пошаговую ролевую игру с элементами мультиплеера. Находится на стадии разработки.', 'Июль 2023 — Октябрь 20234 месяца', 'Infinite Art SolutionsИваново (Ивановская область)Информационные технологии, системная интеграция, интернет... Показать ещеUnity разработчикработал над проектом по созданию карточной roguelike игры наподобие heartstone. карточная игра с блокчейном. была уже готовая основа. дорабатывал различные механики карт - вампиризм, смена владельца и тд. Также делал верстку приложения - переводил на новый UI. И также сделал туториал для игры', 'Январь 2023 — Апрель 20234 месяца', 'Pixel Tale GamesИнформационные технологии, системная интеграция, интернет... Показать ещеразработчик Unityразработка ролевой игры в жанре "выживание" в 2D стилистике. Разработка всех механик игры. Игра доступна по ссылке https://play.google.com/store/apps/details?id=com.pixeltale.survival&hl=ru&gl=US\nразработка прототипа игры с помощью Game Creator для Unity. (игра наподобие sword fighters simulator в Roblox)', 'Февраль 2022 — Декабрь 202211 месяцев', 'Bat ITИнформационные технологии, системная интеграция, интернет... Показать ещеUnity разработчикверстка UI по готовому дизайну в фигме. Разработка клиент-серверных приложений для iOS. Разработка различных механик, оптимизация кода. ', 'Февраль 2021 — Август 20217 месяцев', 'Sky InnovationsКраснодар, skyinnovations.ru/Информационные технологии, системная интеграция, интернет... Показать ещеUnity разработчикразработка мобильного приложения с дополненной реальностью. С использованием AR Foundation. Приложение - квест в дополненной реальности для студентов. Разделение ролей в приложении на учеников и учителей. Учитель может создавать и редактировать квесты, запускать студентов на занятие. Студент подключается по коду и попадает в дополненную реальность, где появляются различные 3D-модели, по щелчку на которые студент выполняет тематический тест. Отслеживание результатов теста онлайн, а также топ-результаты всех студентов, выполняющих квест. \nПолное ведение проекта, разработка на Unity с нуля до релиза, взаимодействие с командой.\nhttps://play.google.com/store/apps/details?id=eu.cleverbooks.arc.quest', 'Июнь 2020 — Февраль 20219 месяцев', 'Remagic DigitalПетрозаводскИнформационные технологии, системная интеграция, интернет... Показать ещеUnity разработчикСоздание механик для мобильных игр и прилож ...
# {'id': '33c9bdde0007c720900039ed1f6330366a646d', 'gender': 'Мужчина', 'age': '34 года', 'date_of_birth': '20 октября 1989', 'about_me': 'Телеграмм для связи @paha_bu. \nХобби: научная фантастика, космос, история, игра на муз. инструментах, компьютерные игры.', 'education': ['Высшее образование2013Московский государственный технический университет им. Н.Э. Баумана, МоскваФакультет биомедицинской техники, инженерное дело в медико-биологической практике'], 'language': ['Знание языковРусский — РоднойАнглийский — C1 — ПродвинутыйИврит — A1 — Начальный'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва', 'moving': 'готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Unity разработчик ', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 13 лет', 'experience': ['Март 2022 — по настоящее время2 года 3 месяца', 'ООО "Филин Про"Москва, filin.pro/Информационные технологии, системная интеграция, интернет... Показать ещеUnity разработчикПрограммирование на движке Unity интерактивных презентаций, мини-игр. Программирование Arduino для управления светодиодными лентами в различных сценариях. \nНаписание логики для UI по готовым дизайнам из Figma. "Подхват" проектов от других разработчиков - внедрение изменений в текущую логику. Работа со Streaming assets и внешними источниками данных (Google tables) для отображения "на лету" в сборке. Работа с webview.', 'Май 2011 — Январь 202210 лет 9 месяцев', 'Медицинская техникаМедицина, фармацевтика, аптеки... Показать ещеСервисный инженер/Руководитель сервисной службы11 лет работал в качестве сервисного инженера/руководителя сервисной службы по медицинской технике в различных компаниях и мед. учрежедниях. '], 'tags': ['Microsoft Access', 'VBA', 'C#', 'Unity', 'Arduino', 'Unity 3D', ' Git', 'Разработка компьютерных Игр', 'Gamedev', 'MVC', 'SOLID', 'Математика', 'MS Excel', ' ООП', 'Умение разбираться в чужом коде', 'Рефакторинг кода', 'Английский язык', 'Основы компьютерных сетей', 'Figma', 'Blender 3D', 'Game Programming'], 'link': 'https://hh.ru/resume/33c9bdde0007c720900039ed1f6330366a646d'}
# {'id': 'b13899fb00086e65080039ed1f365439324f65', 'gender': 'Мужчина', 'age': '', 'date_of_birth': '', 'about_me': 'https://github.com/tarsss/', 'education': ['ОбразованиеСреднее образование'], 'language': ['Знание языковРусский — РоднойАнглийский — C1 — Продвинутый'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Владикавказ', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Middle Unity Developer', 'salary': '130000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 5 месяцев', 'experience': ['Сентябрь 2023 — Октябрь 20232 месяца', 'GameStateСанкт-ПетербургИнформационные технологии, системная интеграция, интернет... Показать ещеUnity DeveloperПоддержка и обновления успешного мобильного проекта с 10+ миллионов установок.', 'Июнь 2020 — Август 20233 года 3 месяца', 'Delta Vision GamesИнформационные технологии, системная интеграция, интернет... Показать ещеUnity DeveloperMobile multiplayer strategy game https://youtu.be/Ke6cQtJQIqo\n(Google Play) Rage of Giants https://youtu.be/Z4MHFqHP7W4\n\n-Разработка с нуля и до релиза на Google Play\n-Быстрое прототипирование \n-Написание клиентского и серверного кода\n-Написание шейдеров (HLSL и Shader Graph)\n-Вёрстка и оптимизация интерфейсов (UGUI)\n-Оптимизация рендеринга (Draw calls, шейдеры, LOD...)\n-Напряженные системы (Pathfinding, AI в RTS игре) (Job System, Burst, data oriented design)\n-Подключение аналитики и инаппов'], 'tags': ['C#', '.NET Framework', 'Unity', 'Git', 'DOTS', 'Burst Compiler', 'Оптимизация', 'Процедурная генерация', 'ООП', 'Mercurial', 'Blender 3D', 'Android'], 'link': 'https://hh.ru/resume/b13899fb00086e65080039ed1f365439324f65'}
# {'id': '902cb192000417ad210039ed1f346a64474d4a', 'gender': 'Мужчина', 'age': '28 лет', 'date_of_birth': '28 июня 1995', 'about_me': '8 лет разрабатываю на unity c#, из них около 4ех лет принимал участие в коммерческой разработке для мобильных платформ.\n\nСтак:\n* OOP / c#\n* UniRx / R3 + UniTask\n* ECS как концепт\n* DOTS\n* Zenject / Reflex\n* DOTween\n* Input System\n* Addressables\n* UI Elements / Toolkit\n* ShaderGraph \n* HLSL \n* HTML / CSS\n\nРаботал поверхностно:\n* SRP / URP\n* VFXGraph (мое https://youtu.be/1f_YpiBGPbI)\n* VR / AR\n* Netcode for GameObjects\n\nGitHub https://github.com/Antoshidza\n\nКак разработчику интересны направления, в которых мало опыта, например клиент-серверная разработка, VR / AR, разработка под WEB, графическая разработка\n\nНа данный момент разрабатываю свой игровой проект и инструмент для рендеринга спрайтов для использования с Entities (DOTS) (https://github.com/Antoshidza/NSprites).\n\nВ работе предпочитаю умные решения быстрым, однако понимаю реалии коммерческой разработки и согласен с ними.', 'education': ['Высшее образование (Магистр)2019Донской государственный технический университет, Ростов-на-ДонуИнформационные системы и технологии'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — Средний'], 'job_search_status': 'Активно ищет работу', 'place_of_residence': 'Ростов-на-Дону', 'moving': 'не готов к переезду', 'business_trip': 'готов к редким командировкам', 'name': 'c# unity developer', 'salary': '150000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 4 года 3 месяца', 'experience': ['Август 2023 — Январь 20246 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансunity разработчикРазработка по контракту проектов на DOTS с использованием моего пакета NSprites. ', 'Февраль 2019 — Октябрь 20223 года 9 месяцев', 'GameFirstРостов-на-Дону, gamefirst.site/Информационные технологии, системная интеграция, интернет... Показать ещеunity разработчикДля меня первым проектом в этой компании оказался Crafty Town. К сожалению в Play Market его больше нет, но зато есть видео https://youtu.be/E001uAj6BF8\nЯ занимался поддержкой проекта, из программистов на этом проекте был только я, начали с устранения багов, добавления минорных фичей. Затем выпустили большое обновление, связанное с переработкой игровой карты, добавлением новых скинов зданий и прочим. (вроде на App Store есть акутальная версия https://apps.apple.com/ru/app/crafty-town-idle-city-builder/id1321833316?l=en)\n\nЧуть позже меня назначили на поддержку релизного проекта Religion Inc (https://play.google.com/store/apps/details?id=com.gamefirst.religioninc). На данном проекте так же начали с устранения большого количества багов, добавления минорных фич, обновления UI, но так же были и крупные обновления. Команда разрабокти на этом проекте уже была больше, делили задачи с вторым разработчиком.\n\nБлиже к концу моей работы в этой компании я также поучаствовал в поддержке игры Save The Earth (https://play.google.com/store/apps/details?id=com.gamefirst.free.strategy.save.the.earth&hl=ru&gl=US), которая была написана на кастомном ECS нашего лида, к сожалению, плотно поработать над игрой не довелось, в основном это были доработки UI и мелкие фиксы. Однако был интересный кейс, связанный с большим кол-вом релизов на разных платформах, от чего в проекте росло кол-во платформо-зависимой логики / ассетов. Для этих целей разработал расширяемую систему удобного переключения контекста проекта, чтобы можно было удобно переключаться между наборами деректив, платформы и прочих платформа-зависимых настроек (какжется юнити недавно предложили собственное решение).\n\nТак же где-то с 2022 года на всех проектах довелось решать задачи с внедрением различных рекламных SDK, совместимых с различными новыми площадками, такими как RuStore,  ...
# {'id': '49ddad640008208b790039ed1f675977515946', 'gender': 'Мужчина', 'age': '27 лет', 'date_of_birth': '27 мая 1996', 'about_me': 'Знаком с принципами ООП, SOLID, DRY, паттернами проектирования и применяю все это на практике. \nУмею работать с Profiler и есть базовые навыки оптимизации приложений . Имеется опыт самостоятельной разработки и публикации игры.\nРаботал со сторонними плагинами и библиотеками (к примеру DOtWeen, Obi rope, Signals, Rayfire, Zenject, Unirx), интегрировал рекламу, аналитику, внутриигровые покупки, есть небольшой опыт с ECS. \nGithub  https://github.com/anthropogen', 'education': ['Среднее специальное образование2014Орловский технологический техникумМастер по установке и эксплуатации оборудования в торговом и общественном питании'], 'language': ['Знание языковРусский — РоднойАнглийский — A2 — Элементарный'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Орел', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Unity developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 7 месяцев', 'experience': ['Апрель 2023 — по настоящее время1 год 2 месяца', 'EidolonUnity developerРазработка игр на Unity и Cocos2d', 'Март 2022 — по настоящее время2 года 3 месяца', 'НеталогияТренер курса по разработке игр на UnityПроверка домашних заданий студентов', 'Июнь 2022 — Март 202310 месяцев', 'VIM DIGITALИнформационные технологии, системная интеграция, интернет... Показать ещеUnity developerРазработка hc, casual, idle игр и прототипов\n- написания проектов с нуля, до публикации в стор;\n- подключение анимаций и визуальных эффектов;\n- верстка UI;\n- работы с векторной алгеброй;\n- написания  игровых механик;\n- Поддержка и развитие существующих проектов\n- интеграции SDK(Facebook, GameAnalytics, Appsflyer, AppMetrica, Applovin, In App Purchasing и другие);\n- оптимизации проектов, использование Profiler', 'Ноябрь 2021 — Июнь 20228 месяцев', 'Dorfer GamesUnity developerРазработка hc, idle игр и прототипов\n- написания проектов с нуля, до публикации в стор;\n- подключение анимаций и визуальных эффектов;\n- верстка UI;\n- работы с векторной алгеброй;\n- написания  игровых механик;\n- Поддержка и развитие существующих проектов\n- интеграции SDK(Facebook, GameAnalytics, Appsflyer, AppMetrica, Applovin, In App Purchasing и другие);\n- оптимизации проектов, использование Profiler'], 'tags': ['Visual Studio C#', 'Unity', 'C#', 'Git', 'LINQ', 'ООП', 'Adobe Photoshop', 'Blender 3D', 'WPF', 'Blender', 'Разработка ПО', 'Рефакторинг кода', 'Разработка мобильных приложений', 'Code review', 'Программирование', 'Умение работать в команде', 'Паттерны проектирования', 'Проектирование систем', 'SOLID', 'Scrum', 'Ecs', 'Typescript', 'Cocos2d'], 'link': 'https://hh.ru/resume/49ddad640008208b790039ed1f675977515946'}
# {'id': 'defa218a00087d522c0039ed1f504678466846', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '1 октября 2002', 'about_me': 'Привет, я Unity C# разработчик. Имею опыт создания мобильных и десктопных, а так же AR/VR приложений. Очень хочу попасть в интересную, веселую и общительную команду, где я смогу развиваться и повышать свою квалификацию. Знаю и использую принципы ООП, паттерны разработки, SOLID и шейдеры (Shader Graph и HLSL/CG). Имеют опыт работы в Photoshop, Blender и Substance Painter\n\nПортфолио:\nhttps://drive.google.com/file/d/1PE3CTMxX_8wCwKpRLnbRueyvMj_TQQDn/view?usp=share_link', 'education': ['Неоконченное высшее образование2027Санкт-Петербургский государственный университет промышленных технологий и дизайна, Санкт-ПетербургИнститут Информационных Технологий и Автоматизации, Прикладная информатика в дизайне'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Санкт-Петербург, м. Купчино', 'moving': 'готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Unity/C# developer', 'salary': '95000 ₽ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день', 'experience_all_period': 'Опыт работы 1 год 4 месяца', 'experience': ['Февраль 2023 — Октябрь 20239 месяцев', 'SEVAAPP OUUnity РазработчикРазработка мобильных и браузерных игр', 'Июль 2021 — Январь 20227 месяцев', 'NovadayUnity РазработчикРазработал AR игру для кофейни и\r\nAR Симулятор квадрокоптера'], 'tags': ['Ответственность', 'Английский язык', 'Unity', 'Git', 'SQL', 'MS Visual Studio', 'Game Programming', 'MVC', 'C#', 'Python', 'C++', 'SOLID', 'ООП', 'Clean Architecture', '.NET Core', 'MySQL', 'Математика', 'Паттерны проектирования', 'Коммуникативная компетентность', 'VR'], 'link': 'https://hh.ru/resume/defa218a00087d522c0039ed1f504678466846'}
# {'id': '95e55ac20001ba5e020039ed1f34376c454457', 'gender': 'Мужчина', 'age': '39 лет', 'date_of_birth': '22 февраля 1985', 'about_me': 'Работа в команде, умею организовывать процесс разработки.\nБыстрая обучаемость\nЧитабельно оформление кода, наличие комментариев, разработка документации, написание отдельных классов для взаимодействия с моим кодом другим разработчикам.\nЦелеустремленность, дисциплинированность\n\nhttps://play.google.com/store/apps/details?id=com.lunaparkgame.kalmarus456\n\nhttps://vk.com/app51801807_102640837 - полностью моя рисовка, и анимация\n\nhttps://play.google.com/store/apps/details?id=com.Radli.DarkWar\n\nНестандартные решения, которые работают хорошо!\n\nПри работе над проектом всегда стараюсь довести его до релиза. Предлагаю свои идеи если будет уместно. Имею опыт организации и управления людьми при необходимости достижения общей поставленной задачи. Опыт на госслужбе.', 'education': ['Высшее образование2007Башкирский государственный аграрный университет, Уфа'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Уфа', 'moving': 'не готов к переезду', 'business_trip': 'готов к редким командировкам', 'name': 'Unity 3D developer', 'salary': '', 'specialization_schedule': 'Специализации: Менеджер продукта Дизайнер, художник Гейм-дизайнер Программист, разработчик Руководитель группы разработки Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 6 лет 5 месяцев', 'experience': ['Январь 2023 — по настоящее время1 год 5 месяцев', 'Cubarus gameМоскваВедущий Unity Developer-Полный цикл разработки игры\n\n- Мультиплеерная часть игры, сетевое взаимодействие, оптимизация игры, синхронизация, написание шейдеров, взаимодействие с бэкендом\n\n- Полный цикл разработки механик и мета части игры в стиле GTA  с захватом домов и взаимодействие с окружающим миром (NPS, объекты, другие игроки)\n\nhttps://apps.rustore.ru/app/com.street.dominator.online', 'Сентябрь 2022 — Февраль 20236 месяцев', 'Top Академия ШАГ ITУфаПреподаватель ITПреподаватель. Unity 3D, UE 4, C#, C++, Python\n', 'Декабрь 2021 — Ноябрь 20221 год', 'Thallium Group LLCСШАВедущий Unity Developer / Senior unity3D developer- Планирование разработки, установка сроков и их соблюдение, ответственность за качество кода, code review\n- Полный цикл разработки приложений на Android / IOS / WebGL (до открытого тестирования)\n- Аналитика\n- AR презентации\n- Ревью кода (Доделывание чужих наработок)\n- Разработка прототипов мобильных игр и приложений на - Unity3d  &  Unreal Engine \n- Level designer, Game designer\n- 2D и 3D контент (когда художник не успевал, или заказчика не устраивало)\n- Концепт и визуал прототипов игр\n- Взаимодействие со стороны клиента во всех приложениях metaverse (награды, бонусы, рейтинг)\n- UX / UI верстка (2d анимация)\n\n', 'Январь 2019 — Январь 20223 года 1 месяц', 'ИП Мясников Андрей ОлеговичРоссияИнформационные технологии, системная интеграция, интернет... Показать ещеВедущий программист unity3d- Разработка игр, прототипов\n- Рефакторинг стороннего кода\n- разработка и внедрение Архитектуры приложения\n- Разработка различных механик;\n- Придумывание и разработка концептов;\n- Создание инструментов для геймдизайнера по согласованию;\n- Доведение проектов до закрытого теста.\n- Организация взаимодействия членов команды\n- Создание 2D контента, дизайн персонажей, подбор стилистики, анимирование (растровая анимация)\n-3D моделирование, текстурирование, риг персонажей\n- Проектирование и проработка UX\\UI\n- Интеграция сторонних SDK\n- Реализация, разработка, и презентация контента по заказу клиента\n- Монтаж трейлеров приложений и игр\n- составление ТЗ и Дизайн документа ', 'Январь 2018 — Декабрь 20203 года', 'Индивидуальное предпринимательство / частная практика / фрилансUnity 3D разработчик- создание и про ...
# {'id': '880e890600084aa11f0039ed1f414c34646d49', 'gender': 'Мужчина', 'age': '23 года', 'date_of_birth': '31 декабря 2000', 'about_me': 'Мои навыки в работе с Unity:\n• реализация игровых механик и логики;\n• вёрстка адаптивного UI;\n• проектирование архитектуры проекта;\n• разработка, с использованием Leo-ECS, Unity JOBS;\n• опыт работы с DoTween, Zenject, OdinInspector, A* Pathfinding и другими инструментами;\n• работа с анимациями (Animator, BlendTree, Layers и т.д.);\n• работа с физикой;\n• работа с визуальной частью (настройка освещения, материалов, цветов);\n• оптимизация приложения, уменьшение размера билда;\n• встраивание сторонних SDK -  рекламы и аналитики (Facebook, Firebase, Applovin, IronSource, Appodeal, AppsFlyer, GameAnalytics, Gadsme, AppMetrica);\n• создание простых инструментов для редактора.\n\nДругие навыки:\n• опыт работы в Blender, Photoshop;\n• опыт использования Git, Trello, Figma.\n\nПримеры проектов, над которыми я работал:\n\nСобственный проект: https://play.google.com/store/apps/details?id=com.woki4.FightingAnimalsParty\n\nРабочие проекты:\nhttps://play.google.com/store/apps/details?id=com.Spider.Hero (10+ млн. скачиваний)\n\nhttps://play.google.com/store/apps/details?id=com.hoopsly.arsenalmerge (1+ млн. скачиваний)\n\nhttps://play.google.com/store/apps/details?id=com.Delivery.Room (1+ млн скачиваний)\n\nhttps://play.google.com/store/apps/details?id=com.Bubble.Gun (100+ тыс. скачиваний)\n\nhttps://play.google.com/store/apps/details?id=com.Traps.Master\n\nhttps://play.google.com/store/apps/details?id=com.backroom.arena\n\nhttps://play.google.com/store/apps/details?id=com.LionLife.RPG\n\nhttps://play.google.com/store/apps/details?id=com.Stickman.Eater\n\nhttps://play.google.com/store/apps/details?id=com.Garage.Master\n\nhttps://play.google.com/store/apps/details?id=com.Idle.Fire\n\nhttps://play.google.com/store/apps/details?id=com.MiniMonsters.Shop', 'education': ['Неоконченное высшее образование2023РТУ МИРЭАИнформационные системы и технологии'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва', 'moving': 'не готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Unity разработчик (C#)', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 2 месяца', 'experience': ['Апрель 2021 — по настоящее время3 года 2 месяца', 'TapOnМоскваUnity-разработчикРазработка Casual игр с нуля до релиза:\n\n• реализация игровых механик и логики;\n• вёрстка адаптивного UI;\n• проектирование архитектуры проекта;\n• работа со сторонними ассетами;\n• работа с анимациями (Animator, BlendTree, Layers и т.д.);\n• работа с физикой;\n• работа с визуальной частью (настройка освещения, материалов, цветов);\n• оптимизация приложения, уменьшение размера билда;\n• встраивание сторонних SDK -  рекламы и аналитики (Facebook, Firebase, Applovin, IronSource, Appodeal, AppsFlyer, GameAnalytics, Gadsme, AppMetrica);\n• создание простых инструментов для редактора.'], 'tags': ['Unity', 'Blender 3D', 'C#', 'Git', 'Adobe Photoshop', 'UI', 'ECS'], 'link': 'https://hh.ru/resume/880e890600084aa11f0039ed1f414c34646d49'}
# ...
# {'id': '6079ca1800017c839b0039ed1f6f6764434a74', 'gender': 'Женщина', 'age': '', 'date_of_birth': '', 'about_me': 'свободное пользование ПК :\r\nWord\r\nExcel (расчет различных формул, построение графиков и д.р.)\r\nPower Point\r\nPhotoshop\r\nFlash\r\nMotion\r\nUnity\r\nAfter Effects\r\nAdobe Premiere\r\nMaya - базовые знания\r\nToon Boom\r\nhtml - базовые знания\r\nпрограмма 1C ( штрих-кассир)\r\nVBA (макросы)\r\nС++ базовые знания,\r\nанглийский устный и письменный, уровень advanced', 'education': ['Высшее образование2013Британская школа высшего дизайна Screem SchoolАнимация2011МФПА (Московская Финансово-Промышленная Академия)Мировая экономика/ Математические методы принятия решений, Финансовая аналитика (Диплом защитила на отлично)2006школа 16профильный класс при экономическом факультете МГУ им Ломоносова.2004школа 1249 с углубленным изучением немецкого языка.углубленное изучение немецкого языка.'], 'language': ['Знание языковРусский — РоднойАнглийский — C2 — В совершенстве'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва, м. Люблино', 'moving': 'не готова к переезду', 'business_trip': 'готова к командировкам', 'name': 'Аниматор', 'salary': '58000 ₽ на руки', 'specialization_schedule': 'Специализации: Артист, актер, аниматор Занятость: полная занятость, частичная занятость График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 12 лет 10 месяцев', 'experience': ['Ноябрь 2013 — по настоящее время10 лет 7 месяцев', 'Arsenta Designarsenta.ruаниматор, моушен-дизайнер, специалист медиа отделасоздание видео роликов промо, рекламного, презентационного характера, инфографика.', 'Январь 2013 — Сентябрь 20139 месяцев', 'LenronМоскваАниматорАнимация персонажей в Flash и SVG, создание и обработка изображений в Photoshop, Illustrator, InkScape, поиск художников, фрилансеров, курирование работы фрилансеров, составление ТЗ для художников, контроль выполнения, отчетность', 'Июнь 2012 — Ноябрь 20126 месяцев', 'Narr8narr8.me/художник-аниматорперекладочная анимация psd файлов (сцен) в Motion, Unity. создание объемных сцен из 2хмерных изображений. timing and spacing.', 'Ноябрь 2011 — Март 20125 месяцев', 'NetCracker Technology Corp.Москва, www.netcracker.com/Маркетинговый аналитикПодготовака различных материалов о продукте и компании для sales-отдела. Написание технических текстов, создание презентаций, брошюр о OSS/BSS системах, продукте создаваемом компанией. Составление индивидуальных решений для клиентов. Создание внутреннего информационного портала.', 'Июнь 2010 — Июль 20102 месяца', 'Тинькофф Кредитные Системы, БанкСпециалист по работе с клиентамиКонсультирование потенциальных и действующих клиентов, удержание претензионных клиентов', 'Июнь 2009 — Октябрь 20095 месяцев', 'ЕК СтудияфотографСъемка предметов и моделей, съемка мебели, составление каталогов, поиск клиентов, составление бюджетов по съемкам'], 'tags': [], 'link': 'https://hh.ru/resume/6079ca1800017c839b0039ed1f6f6764434a74'}
# {'id': 'd4f94878000814f5f80039ed1f36474b476b30', 'gender': 'Male', 'age': '57 years', 'date_of_birth': '25 October 1966', 'about_me': 'Highly innovative, organized, proactive, and strategic leader with a broad information technology background, including experience in infrastructure, security procedures and controls, business continuity and disaster recovery, process improvement, team leadership, and vendor management. Proficient in developing and managing the corporate IT infrastructure, focusing on performance improvements, automation, and documentation. Excellent in leading a team of IT professionals, building solid relationships, mentoring and developing the employees.', 'education': ['Higher education (bachelor)1999Presidential Academy of National Economy and Public AdministrationManagement, Strategic management1992Irkutsk State UniversityMathematics, Applied Mathematics and Informatics'], 'language': ['LanguagesRussian — NativeEnglish — C2 — ProficiencyItalian — A1 — BasicSpanish — A1 — Basic'], 'job_search_status': 'Not looking for a job', 'place_of_residence': 'Canada', 'moving': 'willing to relocate (Russia)', 'business_trip': 'prepared for business trips', 'name': 'IT Director', 'salary': '', 'specialization_schedule': 'Specializations: Development team leader Employment: full time Work schedule: full day', 'experience_all_period': 'Work experience 24 years 11 months', 'experience': ['January 2022 — currently2 years 5 months', 'Royal Bank of CanadaIT Infrastructure Lead• Guide a team of Infrastructure and Dev/Ops analysts. Work on team goals and team performance metrics. Coordinate cross-function team trainings.\n• Closely work with Virtualization, Server, and Security teams to deploy Windows and Linux servers to different application teams.\n• Discuss and refine the resource requirements to keep the best cost/performance balance for all new and existing applications. \n• Collaborate with financial planning teams from different department and lines of business to regularly prepare and deliver reports on infrastructure spending to senior management. \n• Identify the opportunities for cost reduction and process improvements. \n• Automate and document the system builds and maintenance to improve the everyday work. \n', 'January 2021 — December 20211 year', 'University of TorontoCanada, www.utoronto.ca/Educational Institutions... Show moreSenior Systems and Network Supervisor* Manage, configure and improve the IT infrastructure.\n* Review, design and implement security infrastructure for servers and network devices.\n* Supervise, mentor, lead staff in systems administration unit.\n* Coordinate tasks for projects and other strategic initiatives with stakeholders.\n* Develop and update architectural framework for highly complex and confidential university-wide IT systems\n* Plan and lead various IT projects.\n* Troubleshoot and resolve the incidents on highly complex systems.', 'April 2020 — December 20209 months', 'Unity Health Toronto (Unity of three largest hospitals in Toronto)Canada, unityhealth.to/Medicine, Pharmaceuticals, Pharmacies... Show moreSenior Technical Systems Specialist* Design, configure, update and deploy high availability physical and virtual systems.\n* Monitor system capacity utilization and performance; regularly conduct fine tuning and optimization of infrastructure systems.\n* Formalize and document policies, processes, and procedures.\n* Analyze and automate routine processes, improving systems performance and reducing the number of human errors.\n* Troubleshoot the most complex technical issues of IT infrastructure systems and equipment\n* Advise the IT department management on system administration issues including core technical support processes, standard operating procedures, technical standards\n* Actively involved in departmental tactical planning and project management.\n* Provide mentorship and supervision to other technical support and operational staff', 'April 2018 — August 20191 year ...
# {'id': '0aff188400082485690039ed1f4a36796b494c', 'gender': 'Женщина', 'age': '25 лет', 'date_of_birth': '24 июля 1998', 'about_me': '- Владею всеми актуальными графическими пакетами, иллюстрацией, рисунком от руки, программами: Adobe Illustrator, Adobe Photoshop, CorelDRAW, StableDiffusion.\nЗнакома с Adobe Premier Pro, Blender, Unity, AutoCAD.\nИмею:\n- опыт разработки графического контента для игровых проектов с  нуля  до выпуска в релиз: (дизайн персонажей, игровых объектов, иллюстрации, создания дизайна, фонов, интерфейса и пр.);\n- умение работать в стилях: казуальный, семиреализм, sketching, Line art, moodboarding, а также photobash, воксельная, пиксельная графика и др.;\n- насмотренность, креативность и богатая фантазия;\n- высокая скорость работы без потери качества, своевременное выполнение тасков;\n- умение пользоваться референсами и нейросетями;\n- знания законов композиции, колористики, освещения, умение видеть пропорции, художественный вкус и внимание к деталям.\nОбладаю опытом, как индивидуальной работы, так и в составе команды. Работаю на графическом планшете.\nГотова подстраиваться под стилистику проекта и используемый командой инструментарий.\nУмею быстро и объективно оценивать ситуацию, приоритизировать проекты и расставлять фокусы, достигать желаемый результат наиболее эффективными способами.  Внимательна к мелочам, инициативна. \nУмею принимать критику и оперативно вносить требуемые правки.\nАктивно использую новые технологии для развития творческого и профессионального потенциала.', 'education': ['Неоконченное высшее образование2017Российский экономический университет им. Г.В. Плеханова, МоскваВысшая школа технологий, математики и статистики., Информационная безопасность телекоммуникационных систем'], 'language': ['Знание языковРусский — РоднойАнглийский — B2 — Средне-продвинутый'], 'job_search_status': 'Рассматривает предложения', 'place_of_residence': 'Москва, м. Царицыно', 'moving': 'готова к переезду', 'business_trip': 'готова к редким командировкам', 'name': '2D artist', 'salary': '50000 ₽ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Занятость: полная занятость, частичная занятость, проектная работа График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 7 месяцев', 'experience': ['Июнь 2022 — по настоящее время2 года', 'Индивидуальное предпринимательство / частная практика / фрилансФриланс- Провожу встречи с заказчиками, собираю информацию о заказе, составляю эскизы и скейтчи, согласовываю и вношу правки при необходимости. Средний срок исполнения заказа 2-3 дня.\n- Разрабатываю концепты в соответствии с техническим заданием и референсами;\n- Отрисовываю промоматериалы, персонажей, отдельные обьекты, композиции, интерьеры, фоны и т. п., выполняю дизайн по запросу клиентов (принт на одежду, стикерпаки, подарочные открытки, рекламные буклеты, презентации и пр.)\nДостижения:\nВ короткие сроки (4 часа) создала концепцию, согласовала с заказчиком, выполнила сложный принт-дизайн', 'Октябрь 2021 — Май 20228 месяцев', 'СилаММосква, sila-m.ruХудожникОбязанности:\nОтрисовывала геральдические композиции по готовым эскизам и ТЗ (до 22 в месяц):\n- самостоятельный выбор колористики, фактуры, элементов;\n- корректировка векторного макета;\n- отрисовка в растровой графике;\n- согласование на промежуточном этапе, доработка, внесение правок по комментариям арт-лида в короткие сроки.\nДостижения:\nПроработано и отрисовано более сотни индивидуальных гербов и эмблем, от векторного наброска до отправки в печать растрового изображения высокого разрешения.\nМои работы представлены на главном сайте компании https://sila-m.ru', 'Март 2021 — Сентябрь 20217 месяцев', 'BearsCom GamesСанкт-Петербург, vk.com/bearscomgames2D-художникОбязанности:\nРазрабатывала графический контент для игровых проектов Stint: Rift Apart:\n- отсмотр материалов, формирование выборки референсов; \n- подбор референсов для текущей задач;\n- создание шорт-листа ск ...
# {'id': '44a38d7d0009182a1f0039ed1f736c58773838', 'gender': 'Мужчина', 'age': '25 лет', 'date_of_birth': '10 июля 1998', 'about_me': 'Обладаю качествами инициативности, быстрой обучаемости и многозадачности, что позволяет мне быстро погрузиться в любую сферу и максимально быстро войти в рабочий ритм.\n   Неконфликтный, дружелюбный, всегда иду на компромисс! Ищу дружную команду, в которой будет здоровая конкуренция для крутой мотивации!\n   Помимо увлечения сферой дизайна я обожаю видео игры, музыку и активное времяпрепровождение', 'education': ['Высшее образование (Бакалавр)2022Российский университет дружбы народов, МоскваИнженерная академия , Энергетическое машиностроение 2020Московский государственный строительный университет, МоскваИГЭС, Строительство объектов тепловой и атомной энергетики'], 'language': ['Знание языковРусский — РоднойАнглийский — B1 — СреднийНемецкий — A1 — Начальный'], 'job_search_status': 'Не\xa0ищет работу', 'place_of_residence': 'Санкт-Петербург', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Video editor, motion designer', 'salary': '1400 $ на руки', 'specialization_schedule': 'Специализации: Дизайнер, художник Видеооператор, видеомонтажер Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 8 месяцев', 'experience': ['Октябрь 2021 — по настоящее время2 года 8 месяцев', 'VarwinИнформационные технологии, системная интеграция, интернет... Показать ещеVideo editor / motion designer   Полный цикл видеопроизводства: \nНаписание сценариев, съемка и монтаж, саунд-дизайн; создание фирменного стиля, motion графики для трейлеров/тизеров, видео-прохождений, видео-уроков и презентаций;  работа виртуальной камерой в игровых движках и 3D редакторах.\n   \n   Графический дизайн – стилизация 2D/3D контента в рамках фирменного стиля.\n   \n   UX/UI дизайн – разработка и внедрение дизайн решений на основе имеющейся архитектуры, редизайн элементов с целью расширения функционала и удобства взаимодействия.'], 'tags': ['Blender 3D', 'Atlassian Jira', 'Fl studio', 'Adobe Audition', 'Adobe After Effect', 'Adobe Premier Pro', 'Adobe Illustrator', '3D Max', 'Unity', 'Видеомонтаж', 'Видеосъемка', 'Обработка видео', 'Монтаж звука', 'Режиссура', 'Производство рекламных роликов', 'Написание рекламных сценариев', 'Unity Cinemachine Camera', 'Adobe Substance 3D Designer', 'Blender', 'Marmoset Toolbag', 'Adobe Premiere Pro', 'Adobe Photoshop', 'Инфографика', 'Композитинг', 'Цветокоррекция', 'Ретушь', 'Моушн-дизайн', 'Corona Renderer', 'Adobe After Effects', 'Adobe Animate'], 'link': 'https://hh.ru/resume/44a38d7d0009182a1f0039ed1f736c58773838'}

# %% [markdown]
# ### Смотрим, что получилось (функцию запустил на примере 60 ссылок)

# %%
# Прочитаем ссылки из файла csv и сохраним в переменную link_resume_from_csv
with open(f"/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv") as link_csv:
  links = [row[0] for row in csv.reader(link_csv)]

# %%
len (links)
# Out:
# 1189

# %%
# Извлекаем информацию из файла с парсингом резюме при помощи pandas
data_exam = pd.read_csv(f"/content/drive/MyDrive/Practice2/parsinghh/result_resumes_{search}.csv")

# %%
data_exam.head()
# Out:
#                                        id   gender       age    date_of_birth  \
# 0  a988d74c0006dd7e420039ed1f577a6b416431     Male  28 years   6 January 1996
# 1  e8733c290005cf020c0039ed1f746f764f3434  Мужчина    28 лет   2 октября 1995
# 2  cd6318a70007f15eae0039ed1f5950447a524e  Мужчина    30 лет    22 марта 1994
# 3  181756a0000817af6e0039ed1f725933663161  Женщина    28 лет  10 октября 1995
# 4  79f5a5e80007829adf0039ed1f754b49704e74     Male  35 years      20 May 1988
#
#                                             about_me  \
# 0  Живу в г. Минске.\nЖелаемая должность - UX\UI ...
# 1                            Я Senior UX UI Designer
# 2  Ссылка на портфолио: https://www.behance.net/d...
# 3  Всем привет!\nМеня зовут Лиза и я - UX/UI Desi...
# 4  Passionate UI/UX designer with over 7 years of...
#
#                                            education  \
# 0  ['Higher education2017БИП - Институт правоведе...
# 1  ['Неоконченное высшее образование2021Московски...
# 2  ['Высшее образование2015Дальневосточный федера...
# 3  ['Высшее образование2019Санкт-Петербургский го...
# 4  ['Incomplete higher education2014European Huma...
#
#                                             language  \
# 0  ['LanguagesRussian — NativeEnglish — C1 — Adva...
# 1  ['Знание языковРусский — РоднойАнглийский — B1...
# 2  ['Знание языковРусский — РоднойАнглийский — B2...
# 3  ['Знание языковРусский — РоднойАнглийский — B2...
# 4  ['LanguagesRussian — NativeEnglish — B1 — Inte...
#
#               job_search_status                 place_of_residence  \
# 0  Actively searching for a job  Minsk, metro station Molodezhnaya
# 1           Активно ищет работу                    Нижний Новгород
# 2     Рассматривает предложения                             Москва
# 3                Не ищет работу                    Санкт-Петербург
# 4  Actively searching for a job                             Moscow
#
#                                               moving  \
# 0  I want to relocate (Russia, Czech Republic, Po...
# 1                                   готов к переезду
# 2                          готов к переезду (Россия)
# 3                                  готова к переезду
# 4                                willing to relocate
#
#                  business_trip            name salary  \
# 0  prepared for business trips  UX/UI designer    NaN
# 1        готов к командировкам  UX/UI Designer    NaN
# 2        готов к командировкам  UX/UI designer    NaN
# 3       готова к командировкам  UX/UI Designer    NaN
# 4  prepared for business trips  UX/UI Designer    NaN
#
#                              specialization_schedule  \
# 0  Specializations: Designer, artist Employment: ...
# 1  Специализации: Дизайнер, художник Занятость: п...
# 2  Специализации: Дизайнер, художник Занятость: ч...
# 3  Специализации: Дизайнер, художник Занятость: п...
# 4  Specializations: Designer, artist Employment: ...
#
#               experience_all_period  \
# 0  Work experience 4 years 4 months
# 1        Опыт работы 5 лет 3 месяца
# 2         Опыт работы 5 лет 1 месяц
# 3       Опыт работы 6 лет 9 месяцев
# 4   Work experience 7 years 1 month
#
#                                           experience  \
# 0  ['January 2023 — currently1 year 5 months', "F...
# 1  ['Май 2022 — Май 20242 года 1 месяц', 'Egar Cl...
# 2  ['Август 2023 — по настоящее время10 месяцев',...
# 3  ['Октябрь 2023 — по настоящее время8 месяцев',...
# 4  ['November 2022 — January 20241 year 3 months'...
#
#                                                 tags  \
# 0  ['Figma', 'Sketch', 'Miro', 'Adobe XD', 'Princ...
# 1  ['Креативность', 'Web-дизайн', 'Figma', 'Управ...
# 2  ['Figma', 'Photoshop', 'HTML', 'Sony Vegas', '...
# 3  ['UX', 'UI', 'Benchmarking', 'Прототипирование...
# 4  ['UX', 'UI', 'Дизайн интерфейсов', 'Web Design...
#
#                                                 link
# 0  https://hh.ru/resume/a988d74c0006dd7e420039ed1...
# 1  https://hh.ru/resume/e8733c290005cf020c0039ed1...
# 2  https://hh.ru/resume/cd6318a70007f15eae0039ed1...
# 3  https://hh.ru/resume/181756a0000817af6e0039ed1...
# 4  https://hh.ru/resume/79f5a5e80007829adf0039ed1...

# %%
import pandas as pd
import os

directory_path = '/content/drive/MyDrive/Practice2/parsinghh'

# Перебор файлов в директории
for filename in os.listdir(directory_path):
    if filename.startswith("result_") and filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)

        # Проверка, не пуст ли файл
        if os.stat(file_path).st_size > 0:  # Проверяем размер файла
            try:
                df = pd.read_csv(file_path)
                rows_count = len(df)
                print(f"Файл {filename} содержит {rows_count} строк.")
            except pd.errors.EmptyDataError:
                print(f"Файл {filename} пуст.")
        else:
            print(f"Файл {filename} пуст.")
# Перебор файлов в директории
for filename in os.listdir(directory_path):
    if filename.startswith("link_") and filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)

        # Проверка, не пуст ли файл
        if os.stat(file_path).st_size > 0:  # Проверяем размер файла
            try:
                df = pd.read_csv(file_path)
                rows_count = len(df)
                print(f"Файл {filename} содержит {rows_count} строк.")
            except pd.errors.EmptyDataError:
                print(f"Файл {filename} пуст.")
        else:
            print(f"Файл {filename} пуст.")
# Out:
# Файл result_resumes_Kubernetes.csv содержит 230 строк.
# Файл result_resumes_Docker.csv содержит 233 строк.
# Файл result_resumes_AWS.csv содержит 166 строк.
# Файл result_resumes_SQL.csv содержит 780 строк.
# Файл result_resumes_python.csv содержит 465 строк.
# Файл result_resumes_linux.csv содержит 663 строк.
# Файл result_resumes_figma.csv содержит 1338 строк.
# Файл result_resumes_frontend.csv содержит 1189 строк.
# Файл result_resumes_git.csv содержит 2883 строк.
# Файл result_resumes_UI designer.csv содержит 517 строк.
# Файл result_resumes_C#.csv содержит 173 строк.
# Файл link_resume_Kubernetes.csv содержит 232 строк.
# Файл link_resume_AWS.csv содержит 165 строк.
# Файл link_resume_SQL.csv содержит 4275 строк.
# Файл link_resume_python.csv содержит 4275 строк.
# Файл link_resume_linux.csv содержит 3132 строк.
# Файл link_resume_git.csv содержит 516 строк.
# Файл link_resume_lastday.csv содержит 1168 строк.
# Файл link_resume_UI_Designer.csv содержит 530 строк.
# Файл link_resume_C#.csv содержит 4784 строк.
# Файл link_resume_.csv содержит 3164 строк.
# Файл link_resume_frontend.csv содержит 1188 строк.
# Файл link_resume_UI designer.csv содержит 516 строк.

# %%
import pandas as pd
import os

# Путь к директории с файлами
directory_path = '/content/drive/MyDrive/Practice2/parsinghh'

# Список для хранения данных из всех файлов
all_data = []

# Перебор файлов в директории
for filename in os.listdir(directory_path):
    if filename.startswith("result_") and filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)
        # Считывание файла в DataFrame
        df = pd.read_csv(file_path)
        # Добавление DataFrame в список
        all_data.append(df)

# Объединение всех DataFrame в один
combined_df = pd.concat(all_data, ignore_index=True)

# Подсчет строк до удаления дубликатов
original_rows_count = len(combined_df)
print(f"Количество строк до удаления дубликатов: {original_rows_count}")

# Удаление дубликатов
combined_df = combined_df.drop_duplicates()

# Подсчет строк после удаления дубликатов
final_rows_count = len(combined_df)
print(f"Количество строк после удаления дубликатов: {final_rows_count}")

# Сохранение итогового DataFrame в новый CSV файл
output_file_path = os.path.join(directory_path, 'combined_result.csv')
combined_df.to_csv(output_file_path, index=False)
# Out:
# Количество строк до удаления дубликатов: 9022
# Количество строк после удаления дубликатов: 5267

# %%
import pandas as pd
import os

# Путь к директории с файлами
directory_path = '/content/drive/MyDrive/Practice2/parsinghh'

# Список для хранения данных из всех файлов
all_data = []

# Перебор файлов в директории
for filename in os.listdir(directory_path):
    if filename.startswith("result_") and filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)
        # Считывание файла в DataFrame
        df = pd.read_csv(file_path)
        # Добавление DataFrame в список
        all_data.append(df)

# Объединение всех DataFrame в один
combined_df = pd.concat(all_data, ignore_index=True)

# Подсчет строк до удаления дубликатов
original_rows_count = len(combined_df)
print(f"Количество строк до удаления дубликатов: {original_rows_count}")

# Удаление дубликатов только по полю 'id'
combined_df = combined_df.drop_duplicates(subset=['id'])

# Подсчет строк после удаления дубликатов
final_rows_count = len(combined_df)
print(f"Количество строк после удаления дубликатов: {final_rows_count}")

# Сохранение итогового DataFrame в новый CSV файл
output_file_path = os.path.join(directory_path, 'combined_result.csv')
combined_df.to_csv(output_file_path, index=False)
# Out:
# Количество строк до удаления дубликатов: 24855
# Количество строк после удаления дубликатов: 13822
